# %%
# !pip install geopy

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/dummy_addr.csv")

# %%
import geopy

# %%
dir (geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim()
# Out:
# /usr/local/lib/python3.7/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
n = nom.geocode("Eiffel Tower")
print(n.latitude, n.longitude)
# Out:
# 48.858260200000004 2.2944990543196795

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df["Address2"] = df["Name"]+", "+df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]

# %%
df
# Out:
#     ID  ... properties.osm_value
# 0    1  ...              dentist
# 1    2  ...              dentist
# 2    3  ...              dentist
# 3    4  ...              dentist
# 4    5  ...              dentist
# 5    6  ...              dentist
# 6    7  ...              dentist
# 7    8  ...              dentist
# 8    9  ...              dentist
# 9   10  ...              dentist
# 10  11  ...              dentist
# 11  12  ...              dentist
# 12  13  ...              dentist
# 13  14  ...              dentist
#
# [14 rows x 7 columns]

# %%
df["Coordinates"]= df["Address"].apply(nom.geocode)

# %%
df
# Out:
#     ID  ...                                        Coordinates
# 0    1  ...  (Jalan Setia Tropika 1/1, Lisvistonia I-V, Set...
# 1    2  ...  (Jalan Indah 16/5, Taman Bukit Indah, Bukit In...
# 2    3  ...  (Medan Nusa Perintis 6, Gelang Patah, Iskandar...
# 3    4  ...  (Jalan Kebudayaan 1, Taman Universiti, Iskanda...
# 4    5  ...  (Jalan Suria 5, Taman Rinting, Masai, Johor Ba...
# 5    6  ...  (Jalan Nusaria 11/6, Taman Nusantara, Gelang P...
# 6    7  ...  (Jalan Dato Onn 1, Bandar Dato Onn, Tebrau, Jo...
# 7    8  ...  (Jalan Bentara 1, Taman Ungku Tun Aminah, Skud...
# 8    9  ...  (Jalan Kluang-Jemaluang, Kluang, Johor, Malays...
# 9   10  ...  (Jalan Mersing, Kluang, Johor, 86000, Malaysia...
# 10  11  ...  (Jalan Sutera Tanjung, Taman Sutera Utama, Sku...
# 11  12  ...  (Jalan Sutera Tanjung 8/2, Sutera Utama Biz Ce...
# 12  13  ...  (Food Street, Ayer Hitam, Batu Pahat, Johor, M...
# 13  14  ...  (Jalan Persekutuan 1, Kampung Jaya Sepakat, Se...
#
# ...

# %%
df["Latitude"]= df["Coordinates"].apply(lambda x:x.latitude if x != None else None)

# %%
df["Longitude"]= df["Coordinates"].apply(lambda x:x.longitude if x != None else None)

# %%
# Out:
#     ID                                            Address  ...  Latitude   Longitude
# 0    1  Jalan Setia Tropika 1/1, Johor Bahru, Johor, M...  ...  1.544543  103.710639
# 1    2  Jalan Indah 16/5, Iskandar Puteri, Johor, Mala...  ...  1.481417  103.664350
# 2    3  Medan Nusa Perintis 6, Iskandar Puteri, Johor,...  ...  1.450686  103.593512
# 3    4  Jalan Kebudayaan 1, Iskandar Puteri, Johor, Ma...  ...  1.543227  103.631080
# 4    5              Jalan Suria 5, Masai, Johor, Malaysia  ...  1.493725  103.874370
# 5    6  Jalan Nusaria 11/6, Iskandar Puteri, Johor, Ma...  ...  1.459720  103.584302
# 6    7          Jalan Dato Onn 1, Tebrau, Johor, Malaysia  ...  1.561106  103.742789
# 7    8  Jalan Bentara 1, Iskandar Puteri, Johor, Malaysia  ...  1.518006  103.659631
# 8    9    Jalan Kluang-Jemaluang, Kluang, Johor, Malaysia  ...  2.250516  103.584890
# 9   10             Jalan Mersing, Kluang, Johor, Malaysia  ...  2.029881  103.318804
# ...

# %%
df["Coordinates2"]= df["Address2"].apply(nom.geocode)

# %%
df
# Out:
#     ID  ...                                       Coordinates2
# 0    1  ...  (Dental Legacy, Jalan Setia Tropika 1/1, Lisvi...
# 1    2  ...  (Alpha Dental Clinic, Jalan Indah 16/5, Taman ...
# 2    3  ...  (klinik pergigian teoh, Medan Nusa Perintis 6,...
# 3    4  ...  (klinik pergigian amim, Jalan Kebudayaan 1, Ta...
# 4    5  ...  (Klinik Pergigian Amim, Jalan Suria 5, Taman R...
# 5    6  ...  (V-Smile, Jalan Nusaria 11/6, Taman Nusantara,...
# 6    7  ...  (Klinik Pergigian Dental Legacy, Jalan Dato On...
# 7    8  ...  (klinik gigi jb, Jalan Bentara 1, Taman Ungku ...
# 8    9  ...                                               None
# 9   10  ...                                               None
# 10  11  ...  (Klinik Pergigian L&L, Jalan Sutera Tanjung, S...
# 11  12  ...  (Lou Dental Centre, Jalan Sutera Tanjung 8/2, ...
# 12  13  ...                                               None
# 13  14  ...  (Klinik Gigi Haslinda, Jalan Persekutuan 1, Ka...
#
# ...

# %%
df["Latitude2"]= df["Coordinates2"].apply(lambda x:x.latitude if x != None else None)

# %%
df["Longitude2"]= df["Coordinates2"].apply(lambda x:x.longitude if x != None else None)

# %%
df
# Out:
#     ID  ...  Longitude2
# 0    1  ...  103.710694
# 1    2  ...  103.664220
# 2    3  ...  103.592456
# 3    4  ...  103.630711
# 4    5  ...  103.873880
# 5    6  ...  103.584196
# 6    7  ...  103.737281
# 7    8  ...  103.661526
# 8    9  ...         NaN
# 9   10  ...         NaN
# 10  11  ...  103.666772
# 11  12  ...  103.669031
# 12  13  ...         NaN
# 13  14  ...  103.605301
#
# [14 rows x 14 columns]
