# %% [markdown]
# <a href="https://colab.research.google.com/github/booluckgmie/training/blob/main/Scrape_Khutbah_Jumaat_JAIS_2011_current.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# the base url and the page parameter
base_url = 'http://e-masjid.jais.gov.my/index.php/ekhutbah'
page_param = '?page='

# create an empty list to store the results
khutbah_list = []

# loop through all the pages (1 to 228)
for i in range(1, 2):
    # make a request to the page
    response = requests.get(base_url + page_param + str(i))
    # parse the html content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    # find the table with id "pemohon"
    table = soup.find('table', {'id': 'pemohon'})
    # loop through all the rows in the table (except the header row)
    for row in table.find_all('tr')[1:]:
        # extract the data from each cell
        cells = row.find_all('td')
        bil = cells[0].text.strip()
        tarikh = cells[1].text.strip()
        tajuk = cells[2].text.strip()
        versi = cells[3].text.strip()
        fail = cells[4].find('a')['href'].strip()
        # create a dictionary of the data
        khutbah = {
            'bil': bil,
            'tarikh': tarikh,
            'tajuk': tajuk,
            'versi': versi,
            'fail': fail
        }
        # add the dictionary to the list
        khutbah_list.append(khutbah)

# print the results
# for khutbah in khutbah_list:
    # print(khutbah)

df = pd.DataFrame(khutbah_list)
df['fail'] = df['fail'].str[2:]
prefix = 'http://e-masjid.jais.gov.my/'
df['fail'] = df['fail'].apply(lambda x: prefix + x)
df
# Out:
#    bil      tarikh                                              tajuk  \
# 0    1  07-04-2023                              HIKMAH BULAN RAMADHAN
# 1    2  07-04-2023                              HIKMAH BULAN RAMADHAN
# 2    3  07-04-2023                             THE WISDOM OF RAMADAAN
# 3    4  07-04-2023                             THE WISDOM OF RAMADAAN
# 4    5  07-04-2023                         THE WISDOM OF RAMADAAN PDF
# 5    6  07-04-2023                               HIKMAH BULAN RAMADAN
# 6    7  07-04-2023                               HIKMAH BULAN RAMADAN
# 7    8  07-04-2023                           HIKMAH BULAN RAMADAN PDF
# 8    9  31-03-2023            PUASA MENINGKATKAN KETAKWAAN UMAT ISLAM
# 9   10  31-03-2023            PUASA MENINGKATKAN KETAKWAAN UMAT ISLAM
# 10  11  31-03-2023    FASTING INCREASES THE TAQWA OF THE MUSLIM UMMAH
# 11  12  31-03-2023    FASTING INCREASES THE TAQWA OF THE MUSLIM UMMAH
# 12  13  31-03-2023  FASTING INCREASES THE TAQWA OF THE MUSLIM UMMA...
# 13  14  31-03-2023            PUASA MENINGKATKAN KETAKWAAN UMAT ISLAM
# 14  15  31-03-2023            PUASA MENINGKATKAN KETAKWAAN UMAT ISLAM
# 15  16  31-03-2023        PUASA MENINGKATKAN KETAKWAAN UMAT ISLAM PDF
# 16  17  24-03-2023                               LGBT TABIAT SONGSANG
# 17  18  24-03-2023                               LGBT TABIAT SONGSANG
# 18  19  24-03-2023                          LGBT IS A PERVERTED HABIT
# 19  20  24-03-2023                          LGBT IS A PERVERTED HABIT
#
#          versi                                               fail
# 0         Rumi  http://e-masjid.jais.gov.my//uploads/uploads/0...
# 1         Jawi  http://e-masjid.jais.gov.my//uploads/uploads/0...
# 2      English  http://e-masjid.jais.gov.my//uploads/uploads/H...
# 3   Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/H...
# 4   Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/S...
# 5       Manual  http://e-masjid.jais.gov.my//uploads/uploads/M...
# 6   Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/H...
# 7   Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/S...
# 8         Rumi  http://e-masjid.jais.gov.my//uploads/uploads/3...
# 9         Jawi  http://e-masjid.jais.gov.my//uploads/uploads/3...
# 10     English  http://e-masjid.jais.gov.my//uploads/uploads/P...
# 11  Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/P...
# 12  Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/S...
# 13      Manual  http://e-masjid.jais.gov.my//uploads/uploads/M...
# 14  Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/P...
# 15  Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/S...
# 16        Rumi  http://e-masjid.jais.gov.my//uploads/uploads/2...
# 17        Jawi  http://e-masjid.jais.gov.my//uploads/uploads/2...
# 18     English  http://e-masjid.jais.gov.my//uploads/uploads/L...
# 19  Multimedia  http://e-masjid.jais.gov.my//uploads/uploads/L...

# %%
import os

# Create folders for BM and English PDFs
if not os.path.exists('BM'):
    os.makedirs('BM')
if not os.path.exists('English'):
    os.makedirs('English')

# Filter the DataFrame to only include rows where VERSI KHUTBAH is 'Rumi' or 'English'
df_filtered = df[df['versi'].isin(['Rumi', 'English'])]

# Iterate over the rows in the filtered DataFrame
for index, row in df_filtered.iterrows():
    # Check if the 'Fail Khutbah' column contains a PDF link
    if '.pdf' in row['fail']:
        # Download the PDF file and save it to disk
        pdf_url = row['fail']
        response = requests.get(pdf_url)
        # Extract the language from the 'versi' column
        language = row['versi']
        # Create a filename based on the 'tarikh', 'tajuk', and 'versi' columns
        filename = f"{row['tarikh']}_{row['tajuk']}_{row['versi']}.pdf"
        # Save the file to the appropriate folder
        if language == 'Rumi':
            folder = 'English'
        else:
            folder = 'BM'
        with open(os.path.join(folder, filename), 'wb') as f:
            f.write(response.content)
