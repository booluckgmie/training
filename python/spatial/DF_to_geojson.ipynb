# %% [markdown]
# <a href="https://colab.research.google.com/github/booluckgmie/training/blob/main/DF_to_geojson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas -qq

# %%
import pandas as pd
import geopandas as gpd
map = gpd.read_file("https://raw.githubusercontent.com/dosm-malaysia/data-open/main/datasets/geodata/electoral_1_dun.geojson")

# %%
map
# Out:
#        state        parlimen               dun  code_state code_parlimen  \
# 0      Johor   P.140 Segamat  N.01 Buloh Kasap           1         P.140
# 1      Johor   P.140 Segamat     N.02 Jementah           1         P.140
# 2      Johor  P.141 Sekijang      N.03 Pemanis           1         P.141
# 3      Johor  P.141 Sekijang      N.04 Kemelah           1         P.141
# 4      Johor     P.142 Labis       N.05 Tenang           1         P.142
# ..       ...             ...               ...         ...           ...
# 595  Sarawak     P.220 Baram         N.78 Mulu          13         P.220
# 596  Sarawak   P.221 Limbang   N.79 Bukit Kota          13         P.221
# 597  Sarawak   P.221 Limbang   N.80 Batu Danau          13         P.221
# 598  Sarawak     P.222 Lawas   N.81 Ba`Kelalan          13         P.222
# 599  Sarawak     P.222 Lawas   N.82 Bukit Sari          13         P.222
#
#     code_dun code_state_dun                                           geometry
# ...

# %%
geos = map[map['state']== 'Pulau Pinang']

# %%
geos.head()
# Out:
#             state             parlimen                      dun  code_state  \
# 243  Pulau Pinang   P.041 Kepala Batas              N.01 Penaga           7
# 244  Pulau Pinang   P.041 Kepala Batas              N.02 Bertam           7
# 245  Pulau Pinang   P.041 Kepala Batas      N.03 Pinang Tunggal           7
# 246  Pulau Pinang  P.042 Tasek Gelugor  N.04 Permatang Berangan           7
# 247  Pulau Pinang  P.042 Tasek Gelugor          N.05 Sungai Dua           7
#
#     code_parlimen code_dun code_state_dun  \
# 243         P.041     N.01         7_N.01
# 244         P.041     N.02         7_N.02
# 245         P.041     N.03         7_N.03
# 246         P.042     N.04         7_N.04
# 247         P.042     N.05         7_N.05
#
#                                               geometry
# 243  MULTIPOLYGON (((100.37777 5.57968, 100.37970 5...
# 244  MULTIPOLYGON (((100.40425 5.53774, 100.40576 5...
# 245  MULTIPOLYGON (((100.49165 5.56651, 100.50514 5...
# ...

# %% [markdown]
# ### geodataframe to geojson

# %%
geos.to_file("geos.geojson", driver="GeoJSON")

# %% [markdown]
# from pandas_geojson import read_geojson_url <br>
# geo_json = read_geojson_url('[URL]') <br>
#
# ### OR <br>
#
# from pandas_geojson import read_geojson<br>
# geo_json = read_geojson('[FILENAME]')

# %%
# !pip install pandas_geojson -qq

# %%
from pandas_geojson import read_geojson

# %%
geo_json2 = read_geojson('/content/geos.geojson')
geo_json2
# Out:
# {'crs': {'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'},
#   'type': 'name'},
#  'features': [{'geometry': {'coordinates': [[[[100.37777, 5.57968],
#        [100.3797, 5.57998],
#        [100.38218, 5.58423],
#        [100.38432, 5.58456],
#        [100.38728, 5.57797],
#        [100.39419, 5.57945],
#        [100.40949, 5.57182],
#        [100.40878, 5.56724],
#        [100.41067, 5.56611],
#        [100.42436, 5.56254],
#        [100.43193, 5.56534],
#        [100.43272, 5.56136],
#        [100.43536, 5.56065],
#        [100.43559, 5.55182],
#        [100.43464, 5.54364],
#        [100.4317, 5.53943],
#        [100.42988, 5.53159],
#        [100.42389, 5.53489],
#        [100.42219, 5.53394],
#        [100.42397, 5.533],
#        [100.4208, 5.53017],
#        [100.4197, 5.52465],
#        [100.41608, 5.52324],
#        [100.40576, 5.52705],
#        [100.40425, 5.53774],
#        [100.38508, 5.53554],
#        [100.38201, 5.53247],
#        [100.38281, 5.52677],
# ...

# %%
mapgj = gpd.read_file("/content/geos.geojson")
mapgj
# Out:
#            state              parlimen                      dun  code_state  \
# 0   Pulau Pinang    P.041 Kepala Batas              N.01 Penaga           7
# 1   Pulau Pinang    P.041 Kepala Batas              N.02 Bertam           7
# 2   Pulau Pinang    P.041 Kepala Batas      N.03 Pinang Tunggal           7
# 3   Pulau Pinang   P.042 Tasek Gelugor  N.04 Permatang Berangan           7
# 4   Pulau Pinang   P.042 Tasek Gelugor          N.05 Sungai Dua           7
# 5   Pulau Pinang   P.042 Tasek Gelugor    N.06 Telok Ayer Tawar           7
# 6   Pulau Pinang           P.043 Bagan         N.07 Sungai Puyu           7
# 7   Pulau Pinang           P.043 Bagan        N.08 Bagan Jermal           7
# 8   Pulau Pinang           P.043 Bagan         N.09 Bagan Dalam           7
# 9   Pulau Pinang  P.044 Permatang Pauh       N.10 Seberang Jaya           7
# 10  Pulau Pinang  P.044 Permatang Pauh     N.11 Permatang Pasir           7
# ...

# %%
geos.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 40 entries, 243 to 282
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           40 non-null     object
#  1   parlimen        40 non-null     object
#  2   dun             40 non-null     object
#  3   code_state      40 non-null     int64
#  4   code_parlimen   40 non-null     object
#  5   code_dun        40 non-null     object
#  6   code_state_dun  40 non-null     object
#  7   geometry        40 non-null     geometry
# dtypes: geometry(1), int64(1), object(6)
# memory usage: 2.8+ KB

# %%
#from shapely.geometry import polygon

# %%
import json
import urllib.request
  
# Opening JSON file
#f = open('https://raw.githubusercontent.com/dosm-malaysia/data-open/main/datasets/geodata/electoral_1_dun.geojson')
url = 'https://raw.githubusercontent.com/dosm-malaysia/data-open/main/datasets/geodata/electoral_1_dun.geojson'

geo_json = json.load(urllib.request.urlopen(url))

# returns JSON object as a dictionary
#geo_json = json.load(f)

# %%
'''
{'crs': {'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'},
  'type': 'name'},
 'features': [{'geometry': {'coordinates': [[[[102.71346, 2.82949],
       [102.7945, 2.80362],
       [102.89183, 2.6851],
 'type': 'MultiPolygon'},
   'properties': {'code_dun': 'N.01',
    'code_parlimen': 'P.140',
    'code_state': 1,
    'code_state_dun': '1_N.01',
    'dun': 'N.01 Buloh Kasap',
    'parlimen': 'P.140 Segamat',
    'state': 'Johor'},
   'type': 'Feature'},
  {'geometry': {'coordinates': [[[[102.65545, 2.58459],
       [102.65874, 2.58332],
       [102.67669, 2.58388],
    'type': 'MultiPolygon'},
   'properties': {'code_dun': 'N.02',
    'code_parlimen': 'P.140',
    'code_state': 1,
    'code_state_dun': '1_N.02',
    'dun': 'N.02 Jementah',
    'parlimen': 'P.140 Segamat',
    'state': 'Johor'},
   'type': 'Feature'},
  {'geometry': {'coordinates': [[[[102.93984, 2.62852],
       [102.96909, 2.5959],
       [102.96175, 2.5642],
'''
# Out:
# "\n{'crs': {'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'},\n  'type': 'name'},\n 'features': [{'geometry': {'coordinates': [[[[102.71346, 2.82949],\n       [102.7945, 2.80362],\n       [102.89183, 2.6851],\n 'type': 'MultiPolygon'},\n   'properties': {'code_dun': 'N.01',\n    'code_parlimen': 'P.140',\n    'code_state': 1,\n    'code_state_dun': '1_N.01',\n    'dun': 'N.01 Buloh Kasap',\n    'parlimen': 'P.140 Segamat',\n    'state': 'Johor'},\n   'type': 'Feature'},\n  {'geometry': {'coordinates': [[[[102.65545, 2.58459],\n       [102.65874, 2.58332],\n       [102.67669, 2.58388],\n    'type': 'MultiPolygon'},\n   'properties': {'code_dun': 'N.02',\n    'code_parlimen': 'P.140',\n    'code_state': 1,\n    'code_state_dun': '1_N.02',\n    'dun': 'N.02 Jementah',\n    'parlimen': 'P.140 Segamat',\n    'state': 'Johor'},\n   'type': 'Feature'},\n  {'geometry': {'coordinates': [[[[102.93984, 2.62852],\n       [102.96909, 2.5959],\n       [102.96175, 2.5642],\n"

# %%
#geo_json

# %%
from shapely.geometry import MultiPoint
import pyproj

# %%
#geo_json = gpd.GeoDataFrame(geo_json, crs=4326)
geos = geos.to_crs(epsg=4326)

# %%
geos.head()
# Out:
#             state             parlimen                      dun  code_state  \
# 243  Pulau Pinang   P.041 Kepala Batas              N.01 Penaga           7
# 244  Pulau Pinang   P.041 Kepala Batas              N.02 Bertam           7
# 245  Pulau Pinang   P.041 Kepala Batas      N.03 Pinang Tunggal           7
# 246  Pulau Pinang  P.042 Tasek Gelugor  N.04 Permatang Berangan           7
# 247  Pulau Pinang  P.042 Tasek Gelugor          N.05 Sungai Dua           7
#
#     code_parlimen code_dun code_state_dun  \
# 243         P.041     N.01         7_N.01
# 244         P.041     N.02         7_N.02
# 245         P.041     N.03         7_N.03
# 246         P.042     N.04         7_N.04
# 247         P.042     N.05         7_N.05
#
#                                               geometry
# 243  MULTIPOLYGON (((100.37777 5.57968, 100.37970 5...
# 244  MULTIPOLYGON (((100.40425 5.53774, 100.40576 5...
# 245  MULTIPOLYGON (((100.49165 5.56651, 100.50514 5...
# ...

# %%
import geopandas as gpd
import pandas as pd
import json
from shapely.geometry import shape

def parse_geom(geom_str):
    try:
        return shape(json.loads(geom_str))
    except (TypeError, AttributeError):  # Handle NaN and empty strings
        return None

# %%
#df = pd.read_csv('path/to/your.csv')
geos["geometry"] = geos["geometry"].apply(parse_geom)
geos2 = gpd.GeoDataFrame(geos, geometry="geometry")
geos2.head()
# Out:
#             state             parlimen                      dun  code_state  \
# 243  Pulau Pinang   P.041 Kepala Batas              N.01 Penaga           7
# 244  Pulau Pinang   P.041 Kepala Batas              N.02 Bertam           7
# 245  Pulau Pinang   P.041 Kepala Batas      N.03 Pinang Tunggal           7
# 246  Pulau Pinang  P.042 Tasek Gelugor  N.04 Permatang Berangan           7
# 247  Pulau Pinang  P.042 Tasek Gelugor          N.05 Sungai Dua           7
#
#     code_parlimen code_dun code_state_dun geometry
# 243         P.041     N.01         7_N.01     None
# 244         P.041     N.02         7_N.02     None
# 245         P.041     N.03         7_N.03     None
# 246         P.042     N.04         7_N.04     None
# 247         P.042     N.05         7_N.05     None

# %%
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

# %%
# Use WGS 84 (epsg:4326) as the geographic coordinate system
geos = geos.to_crs(epsg=4326)
print(geos.crs)
geos.head()
# Out:
# epsg:4326
#             state             parlimen                      dun  code_state  \
# 243  Pulau Pinang   P.041 Kepala Batas              N.01 Penaga           7
# 244  Pulau Pinang   P.041 Kepala Batas              N.02 Bertam           7
# 245  Pulau Pinang   P.041 Kepala Batas      N.03 Pinang Tunggal           7
# 246  Pulau Pinang  P.042 Tasek Gelugor  N.04 Permatang Berangan           7
# 247  Pulau Pinang  P.042 Tasek Gelugor          N.05 Sungai Dua           7
#
#     code_parlimen code_dun code_state_dun  \
# 243         P.041     N.01         7_N.01
# 244         P.041     N.02         7_N.02
# 245         P.041     N.03         7_N.03
# 246         P.042     N.04         7_N.04
# 247         P.042     N.05         7_N.05
#
#                                               geometry
# 243  MULTIPOLYGON (((100.37777 5.57968, 100.37970 5...
# 244  MULTIPOLYGON (((100.40425 5.53774, 100.40576 5...
# 245  MULTIPOLYGON (((100.49165 5.56651, 100.50514 5...
# ...

# %%
geos.plot(figsize=(6, 6))
plt.show()

# %%
m = folium.Map(location=[5.398948,100.430115], zoom_start=10, tiles='CartoDB positron')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for _, r in map.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.001)
    #geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_json2,
                           style_function=lambda x: {'fillColor': 'orange'})
    folium.Popup(r['dun']).add_to(geo_j)
    geo_j.add_to(m)

# %%
geo_j = folium.GeoJson(data=geo_json2, style_function=lambda x: {'fillColor': 'orange'})
folium.Popup(r['dun']).add_to(geo_j)
geo_j.add_to(m)

# %%
m
