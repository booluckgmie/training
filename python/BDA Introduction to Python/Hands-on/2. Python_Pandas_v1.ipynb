# %% [markdown]
# ## Manupulating data using pandas

# %% [markdown]
# **Prepared by** <br>
# Nur Hurriyatul Huda Abdullah Sani (nurhuda@dosm.gov.my)

# %% [markdown]
# # Introduction to Pandas
#
# In this section of the course we will learn how to use pandas for data analysis.
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language
# You can think of pandas as an extremely powerful version of Excel, with a lot more features. In this section of the course, you should go through the Pandas in this order:
#
# * Introduction to Pandas
# * Series
# * DataFrames
# * Missing Data
# * GroupBy
# * Merging,Joining,and Concatenating
# * Operations
# * Data Input and Output

# %% [markdown]
# Reference:<br>
# .[1]. https://pandas.pydata.org/docs/user_guide/index.html#user-guide

# %% [markdown]
# First you must have pandas library which can be installed using this command

# %%
# !pip install pandas

# %% [markdown]
# Import Pandas library using this command

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %% [markdown]
# The first main data type we will learn about for pandas is the Series data type.
#
# A Series is very similar to a NumPy array (it is built on top of the NumPy array object).
#
# What differentiates the NumPy array from a Series?
#
# 1) is that a Series can have axis labels, meaning it can be indexed by a label, instead of just a number location.
#
# 2) It also doesn't need to hold numeric data, it can hold any Python Object.
#
# Let's explore this concept through some examples:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# You can convert a list,numpy array, or dictionary to a Series:

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %% [markdown]
# Using Lists

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# NumPy Arrays

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %% [markdown]
# Dictionary

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ## Using an Index

# %% [markdown]
# The key of using a Series is understanding its index. Pandas makes use of these index names or numbers by allowing for fast look ups of information

# %%
ser1 = pd.Series([1,2,3,4],index = ['USA', 'Germany','USSR', 'Japan'])

# %%
ser2 = pd.Series([6,7,8,9],index = ['USA', 'Germany','Italy', 'Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2
# Out:
# USA        6
# Germany    7
# Italy      8
# Japan      9
# dtype: int64

# %%
ser1[0]
# Out:
# 1

# %%
ser2[3]
# Out:
# 9

# %% [markdown]
# Operations are then also done based off of index:

# %%
ser1 + ser2
# Out:
# Germany     9.0
# Italy       NaN
# Japan      13.0
# USA         7.0
# USSR        NaN
# dtype: float64

# %% [markdown]
# ## DataFrames

# %% [markdown]
# One basic structure that you get with pandas is a data frame. A data frame is a two dimensional grid, rather similar to a relational database table except in memory.
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language.
#
# We can think of a DataFrame as a bunch of Series objects put together to share the same index

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# ?np.random

# %% [markdown]
# ## Selection and Indexing

# %% [markdown]
# How to grab data from a DataFrame

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %% [markdown]
# **Removing Columns**

# %%
df.drop('new',axis=1) 

# axis = 1 is referring to column
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# but the 'new' column not permenantly deleted from memory

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %% [markdown]
# Not inplace unless specified!

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# **Removing Rows**

# %%
df.drop('E',axis=0)
# axis = 0 is referring to column
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %% [markdown]
# **Selecting Rows**

# %%
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %% [markdown]
# Or you can select based on position instead of label

# %%
df.iloc[2]

# will select index row 2
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
df.iloc[:,2]

# will select column 2
# Out:
# A    0.907969
# B   -0.848077
# C    0.528813
# D   -0.933237
# E    2.605967
# Name: Y, dtype: float64

# %% [markdown]
# **Selecting subset of rows and columns **

# %%
df.loc['B','Y']
# Out:
# -0.8480769834036315

# %%
df.loc[['A','B'],['W','Y']]

# will select kind of matrix AW AY BW BY
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# **Example 1**

# %%
##{key : list[]:value[]}

data = {'state': ['Jakarta', 'Jakarta', 'Jakarta', 'Selangor', 'Selangor','Kelantan','Kelantan'],
       'year': [2000, 2001, 2002, 2001, 2002, 2001, 2002],
       'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 1.2, 3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#       state  year  pop
# 0   Jakarta  2000  1.5
# 1   Jakarta  2001  1.7
# 2   Jakarta  2002  3.6
# 3  Selangor  2001  2.4
# 4  Selangor  2002  2.9
# 5  Kelantan  2001  1.2
# 6  Kelantan  2002  3.2

# %% [markdown]
# **Rearrange the column**

# %%
frame = pd.DataFrame(data, columns=['year', 'state', 'pop'])
frame
# Out:
#    year     state  pop
# 0  2000   Jakarta  1.5
# 1  2001   Jakarta  1.7
# 2  2002   Jakarta  3.6
# 3  2001  Selangor  2.4
# 4  2002  Selangor  2.9
# 5  2001  Kelantan  1.2
# 6  2002  Kelantan  3.2

# %% [markdown]
# **Adding new column**

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                     index = ['one', 'two', 'three', 'four', 'five', 'six','seven'])
frame2
# Out:
#        year     state  pop debt
# one    2000   Jakarta  1.5  NaN
# two    2001   Jakarta  1.7  NaN
# three  2002   Jakarta  3.6  NaN
# four   2001  Selangor  2.4  NaN
# five   2002  Selangor  2.9  NaN
# six    2001  Kelantan  1.2  NaN
# seven  2002  Kelantan  3.2  NaN

# %% [markdown]
# **Selecting column**

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2['state']
# Out:
# one       Jakarta
# two       Jakarta
# three     Jakarta
# four     Selangor
# five     Selangor
# six      Kelantan
# seven    Kelantan
# Name: state, dtype: object

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2001
# seven    2002
# Name: year, dtype: int64

# %%
frame2.loc['two']
# Out:
# year        2001
# state    Jakarta
# pop          1.7
# debt         NaN
# Name: two, dtype: object

# %% [markdown]
#  loc is location<br>
#  will list all elements under loc [two].<br>
#  loc will call base on assignee name

# %%
frame2.loc['two','state']
# Out:
# 'Jakarta'

# %%
## iloc  base on index

frame2.iloc[1,1]
# Out:
# 'Jakarta'

# %%
frame2.loc['two':,:'state']
# Out:
#        year     state
# two    2001   Jakarta
# three  2002   Jakarta
# four   2001  Selangor
# five   2002  Selangor
# six    2001  Kelantan
# seven  2002  Kelantan

# %%
frame2
# Out:
#        year     state  pop debt
# one    2000   Jakarta  1.5  NaN
# two    2001   Jakarta  1.7  NaN
# three  2002   Jakarta  3.6  NaN
# four   2001  Selangor  2.4  NaN
# five   2002  Selangor  2.9  NaN
# six    2001  Kelantan  1.2  NaN
# seven  2002  Kelantan  3.2  NaN

# %% [markdown]
# **The debt value is NaN. We can assign value for 'debt'**

# %%
frame2['debt'] = 16.5
frame2
# Out:
#        year     state  pop  debt
# one    2000   Jakarta  1.5  16.5
# two    2001   Jakarta  1.7  16.5
# three  2002   Jakarta  3.6  16.5
# four   2001  Selangor  2.4  16.5
# five   2002  Selangor  2.9  16.5
# six    2001  Kelantan  1.2  16.5
# seven  2002  Kelantan  3.2  16.5

# %%
frame2['debt'] = np.arange(7.)
frame2
# Out:
#        year     state  pop  debt
# one    2000   Jakarta  1.5   0.0
# two    2001   Jakarta  1.7   1.0
# three  2002   Jakarta  3.6   2.0
# four   2001  Selangor  2.4   3.0
# five   2002  Selangor  2.9   4.0
# six    2001  Kelantan  1.2   5.0
# seven  2002  Kelantan  3.2   6.0

# %%
frame2['debt'] = [10,20,15,13,11,67,87]
frame2
# Out:
#        year     state  pop  debt
# one    2000   Jakarta  1.5    10
# two    2001   Jakarta  1.7    20
# three  2002   Jakarta  3.6    15
# four   2001  Selangor  2.4    13
# five   2002  Selangor  2.9    11
# six    2001  Kelantan  1.2    67
# seven  2002  Kelantan  3.2    87

# %%
'Jakarta' in frame2.columns
# Out:
# False

# %% [markdown]
# # Use Case Exercise

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **DATA 1**
#
# Call data from Local Drive (downloaded files)

# %%
from google.colab import files
data_to_load = files.upload()

# %%
import io
df = pd.read_csv(io.BytesIO(data_to_load['data2.csv']))

# %% [markdown]
# If we call data directly from python in our machine (laptop/pc) we can use below syntax:

# %%
# df = pd.read_csv('data2.csv')

# %% [markdown]
# **Checking Top 5 and bottom 5 data**

# %%
df.head()
# Out:
#      COUNTRY  POPULATION     AREA       GDP CONTINENTS     IND_DAY
# 0      China     1398.72  9596.96  12234.78       Asia         NaN
# 1      India     1351.16  3287.26   2575.67       Asia   15/8/1947
# 2         US      329.74  9833.52  19485.39  N.America  1776-07-04
# 3  Indonesia      268.07  1910.93   1015.54       Asia   17/8/1945
# 4     Brazil      210.32  8515.77   2055.51  S.America  1822-09-07

# %%
df.tail()
# Out:
#        COUNTRY  POPULATION     AREA      GDP CONTINENTS     IND_DAY
# 15   Argentina       44.94  2780.40   637.49  S.America  1816-07-09
# 16     Algeria       43.38  2381.74   167.56     Africa    5/7/1962
# 17      Canada       37.59  9984.67  1647.12  N.America  1867-07-01
# 18   Australia       25.47  7692.02  1408.68    Oceania         NaN
# 19  Kazakhstan       18.53  2724.90   159.41       Asia  16/12/1991

# %%
df.dtypes
# Out:
# COUNTRY        object
# POPULATION    float64
# AREA          float64
# GDP           float64
# CONTINENTS     object
# IND_DAY        object
# dtype: object

# %%
df.shape
# Out:
# (20, 6)

# %% [markdown]
# **Is there any null value in your data? Let's check them out**

# %%
pd.isnull(df)
# Out:
#     COUNTRY  POPULATION   AREA    GDP  CONTINENTS  IND_DAY
# 0     False       False  False  False       False     True
# 1     False       False  False  False       False    False
# 2     False       False  False  False       False    False
# 3     False       False  False  False       False    False
# 4     False       False  False  False       False    False
# 5     False       False  False  False       False    False
# 6     False       False  False  False       False    False
# 7     False       False  False  False       False    False
# 8     False       False  False  False        True    False
# 9     False       False  False  False       False    False
# 10    False       False  False  False       False     True
# 11    False       False  False  False       False     True
# 12    False       False  False  False       False    False
# 13    False       False  False  False       False     True
# 14    False       False  False  False       False     True
# 15    False       False  False  False       False    False
# 16    False       False  False  False       False    False
# 17    False       False  False  False       False    False
# 18    False       False  False  False       False     True
# 19    False       False  False  False       False    False

# %% [markdown]
# **Create new data frame from the original df**

# %%
newdf1=df[['COUNTRY','POPULATION','CONTINENTS','IND_DAY']]
newdf1
# Out:
#        COUNTRY  POPULATION CONTINENTS     IND_DAY
# 0        China     1398.72       Asia         NaN
# 1        India     1351.16       Asia   15/8/1947
# 2           US      329.74  N.America  1776-07-04
# 3    Indonesia      268.07       Asia   17/8/1945
# 4       Brazil      210.32  S.America  1822-09-07
# 5     Pakistan      205.71       Asia   14/8/1947
# 6      Nigeria      200.96     Africa   1/10/1960
# 7   Bangladesh      167.09       Asia   26/3/1971
# 8       Russia      146.79        NaN   12/6/1992
# 9       Mexico      126.58  N.America  1810-09-16
# 10       Japan      126.22       Asia         NaN
# 11     Germany       83.02     Europe         NaN
# 12      France       67.02     Europe  1789-07-14
# 13          UK       66.44     Europe         NaN
# 14       Italy       60.36     Europe         NaN
# 15   Argentina       44.94  S.America  1816-07-09
# 16     Algeria       43.38     Africa    5/7/1962
# 17      Canada       37.59  N.America  1867-07-01
# 18   Australia       25.47    Oceania         NaN
# 19  Kazakhstan       18.53       Asia  16/12/1991

# %%
newdf1['CONTINENTS'].fillna('transcontinental')
# Out:
# 0                 Asia
# 1                 Asia
# 2            N.America
# 3                 Asia
# 4            S.America
# 5                 Asia
# 6               Africa
# 7                 Asia
# 8     transcontinental
# 9            N.America
# 10                Asia
# 11              Europe
# 12              Europe
# 13              Europe
# 14              Europe
# 15           S.America
# 16              Africa
# 17           N.America
# 18             Oceania
# 19                Asia
# Name: CONTINENTS, dtype: object

# %%
newdf1

#no changes in Rusia
# Out:
#        COUNTRY  POPULATION CONTINENTS     IND_DAY
# 0        China     1398.72       Asia         NaN
# 1        India     1351.16       Asia   15/8/1947
# 2           US      329.74  N.America  1776-07-04
# 3    Indonesia      268.07       Asia   17/8/1945
# 4       Brazil      210.32  S.America  1822-09-07
# 5     Pakistan      205.71       Asia   14/8/1947
# 6      Nigeria      200.96     Africa   1/10/1960
# 7   Bangladesh      167.09       Asia   26/3/1971
# 8       Russia      146.79        NaN   12/6/1992
# 9       Mexico      126.58  N.America  1810-09-16
# 10       Japan      126.22       Asia         NaN
# 11     Germany       83.02     Europe         NaN
# 12      France       67.02     Europe  1789-07-14
# 13          UK       66.44     Europe         NaN
# 14       Italy       60.36     Europe         NaN
# 15   Argentina       44.94  S.America  1816-07-09
# 16     Algeria       43.38     Africa    5/7/1962
# 17      Canada       37.59  N.America  1867-07-01
# 18   Australia       25.47    Oceania         NaN
# 19  Kazakhstan       18.53       Asia  16/12/1991

# %%
newdf1['CONTINENTS'].fillna('Transcontinental', inplace=True)
newdf1
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\series.py:4469: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#        COUNTRY  POPULATION        CONTINENTS     IND_DAY
# 0        China     1398.72              Asia         NaN
# 1        India     1351.16              Asia   15/8/1947
# 2           US      329.74         N.America  1776-07-04
# 3    Indonesia      268.07              Asia   17/8/1945
# 4       Brazil      210.32         S.America  1822-09-07
# 5     Pakistan      205.71              Asia   14/8/1947
# 6      Nigeria      200.96            Africa   1/10/1960
# 7   Bangladesh      167.09              Asia   26/3/1971
# 8       Russia      146.79  Transcontinental   12/6/1992
# 9       Mexico      126.58         N.America  1810-09-16
# 10       Japan      126.22              Asia         NaN
# 11     Germany       83.02            Europe         NaN
# 12      France       67.02            Europe  1789-07-14
# 13          UK       66.44            Europe         NaN
# 14       Italy       60.36            Europe         NaN
# 15   Argentina       44.94         S.America  1816-07-09
# 16     Algeria       43.38            Africa    5/7/1962
# 17      Canada       37.59         N.America  1867-07-01
# 18   Australia       25.47           Oceania         NaN
# 19  Kazakhstan       18.53              Asia  16/12/1991

# %%
newdf1.dtypes
# Out:
# COUNTRY        object
# POPULATION    float64
# CONTINENTS     object
# IND_DAY        object
# dtype: object

# %% [markdown]
# **How to change data to date format**

# %%
# ?pd.to_datetime

# %%
newdf1['IND_DAY']=pd.to_datetime(newdf1['IND_DAY'])
newdf1
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        COUNTRY  POPULATION        CONTINENTS    IND_DAY
# 0        China     1398.72              Asia        NaT
# 1        India     1351.16              Asia 1947-08-15
# 2           US      329.74         N.America 1776-07-04
# 3    Indonesia      268.07              Asia 1945-08-17
# 4       Brazil      210.32         S.America 1822-09-07
# 5     Pakistan      205.71              Asia 1947-08-14
# 6      Nigeria      200.96            Africa 1960-01-10
# 7   Bangladesh      167.09              Asia 1971-03-26
# 8       Russia      146.79  Transcontinental 1992-12-06
# 9       Mexico      126.58         N.America 1810-09-16
# 10       Japan      126.22              Asia        NaT
# 11     Germany       83.02            Europe        NaT
# 12      France       67.02            Europe 1789-07-14
# 13          UK       66.44            Europe        NaT
# 14       Italy       60.36            Europe        NaT
# 15   Argentina       44.94         S.America 1816-07-09
# 16     Algeria       43.38            Africa 1962-05-07
# 17      Canada       37.59         N.America 1867-07-01
# 18   Australia       25.47           Oceania        NaT
# 19  Kazakhstan       18.53              Asia 1991-12-16

# %%
newdf1.dtypes
# Out:
# COUNTRY               object
# POPULATION           float64
# CONTINENTS            object
# IND_DAY       datetime64[ns]
# dtype: object

# %% [markdown]
# **How to fill in missing date**

# %%
newdf1['IND_DAY'].fillna(pd.Timestamp("20210430"))
# Out:
# 0    2021-04-30
# 1    1947-08-15
# 2    1776-07-04
# 3    1945-08-17
# 4    1822-09-07
# 5    1947-08-14
# 6    1960-01-10
# 7    1971-03-26
# 8    1992-12-06
# 9    1810-09-16
# 10   2021-04-30
# 11   2021-04-30
# 12   1789-07-14
# 13   2021-04-30
# 14   2021-04-30
# 15   1816-07-09
# 16   1962-05-07
# 17   1867-07-01
# 18   2021-04-30
# 19   1991-12-16
# Name: IND_DAY, dtype: datetime64[ns]

# %%
newdf1['IND_DAY'].astype(str).replace({'NaT': "No date"})
# Out:
# 0        No date
# 1     1947-08-15
# 2     1776-07-04
# 3     1945-08-17
# 4     1822-09-07
# 5     1947-08-14
# 6     1960-01-10
# 7     1971-03-26
# 8     1992-12-06
# 9     1810-09-16
# 10       No date
# 11       No date
# 12    1789-07-14
# 13       No date
# 14       No date
# 15    1816-07-09
# 16    1962-05-07
# 17    1867-07-01
# 18       No date
# 19    1991-12-16
# Name: IND_DAY, dtype: object

# %%
newdf1['IND_DAY'].fillna(value = 'No date')
# Out:
# 0                 No date
# 1     1947-08-15 00:00:00
# 2     1776-07-04 00:00:00
# 3     1945-08-17 00:00:00
# 4     1822-09-07 00:00:00
# 5     1947-08-14 00:00:00
# 6     1960-01-10 00:00:00
# 7     1971-03-26 00:00:00
# 8     1992-12-06 00:00:00
# 9     1810-09-16 00:00:00
# 10                No date
# 11                No date
# 12    1789-07-14 00:00:00
# 13                No date
# 14                No date
# 15    1816-07-09 00:00:00
# 16    1962-05-07 00:00:00
# 17    1867-07-01 00:00:00
# 18                No date
# 19    1991-12-16 00:00:00
# Name: IND_DAY, dtype: object

# %%
newdf1['IND_DAY'].fillna(value = 'No date', inplace = True)
newdf1
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\series.py:4469: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#        COUNTRY  POPULATION        CONTINENTS              IND_DAY
# 0        China     1398.72              Asia              No date
# 1        India     1351.16              Asia  1947-08-15 00:00:00
# 2           US      329.74         N.America  1776-07-04 00:00:00
# 3    Indonesia      268.07              Asia  1945-08-17 00:00:00
# 4       Brazil      210.32         S.America  1822-09-07 00:00:00
# 5     Pakistan      205.71              Asia  1947-08-14 00:00:00
# 6      Nigeria      200.96            Africa  1960-01-10 00:00:00
# 7   Bangladesh      167.09              Asia  1971-03-26 00:00:00
# 8       Russia      146.79  Transcontinental  1992-12-06 00:00:00
# 9       Mexico      126.58         N.America  1810-09-16 00:00:00
# 10       Japan      126.22              Asia              No date
# 11     Germany       83.02            Europe              No date
# 12      France       67.02            Europe  1789-07-14 00:00:00
# 13          UK       66.44            Europe              No date
# 14       Italy       60.36            Europe              No date
# 15   Argentina       44.94         S.America  1816-07-09 00:00:00
# 16     Algeria       43.38            Africa  1962-05-07 00:00:00
# 17      Canada       37.59         N.America  1867-07-01 00:00:00
# 18   Australia       25.47           Oceania              No date
# 19  Kazakhstan       18.53              Asia  1991-12-16 00:00:00

# %% [markdown]
# **Add new data set call 'data3'**

# %%
from google.colab import files
data_to_load = files.upload()

# %%
import io
df1 = pd.read_csv(io.BytesIO(data_to_load['data3.csv']), encoding='latin-1')

# %%
# if using directly from python or jupyter notebook
df1 = pd.read_csv('data3.csv')
df1
# Out:
#               country       cases   deaths             region
# 0       United States  32,669,121  584,226      North America
# 1               India  16,257,309  186,928               Asia
# 2              Brazil  14,172,139  383,757      South America
# 3              France   5,408,606  102,164             Europe
# 4              Russia   4,736,121  107,103             Europe
# ..                ...         ...      ...                ...
# 215        MS Zaandam           9        2                NaN
# 216           Vanuatu           4        1  Australia/Oceania
# 217  Marshall Islands           4        0  Australia/Oceania
# 218             Samoa           3        0  Australia/Oceania
# 219        Micronesia           1        0  Australia/Oceania
#
# [220 rows x 4 columns]

# %%
df1.dtypes
# Out:
# country    object
# cases      object
# deaths     object
# region     object
# dtype: object

# %%
df1.shape
# Out:
# (220, 4)

# %% [markdown]
# **Change Data Type** <br>
# change cases and death to float

# %%
df1['deaths'] = df1['deaths'].str.replace(',','')
df1['deaths'] = df1.deaths.astype(float)
df1['cases'] = df1['cases'].str.replace(',','')
df1['cases'] = df1.cases.astype(float)

# %%
df1.dtypes
# Out:
# country     object
# cases      float64
# deaths     float64
# region      object
# dtype: object

# %%
df.head(2)
# Out:
#   COUNTRY  POPULATION     AREA       GDP CONTINENTS    IND_DAY
# 0   China     1398.72  9596.96  12234.78       Asia        NaN
# 1   India     1351.16  3287.26   2575.67       Asia  15/8/1947

# %%
df1.head(2)
# Out:
#          country       cases    deaths         region
# 0  United States  32669121.0  584226.0  North America
# 1          India  16257309.0  186928.0           Asia

# %% [markdown]
# **Setting header to data case**

# %% [markdown]
# Different way writing the header.
# Let's change it.

# %%
# .capitalize to change first letter as capital letter.
df1.columns=df1.columns.str.capitalize()  
df1.head(2)
# Out:
#          Country       Cases    Deaths         Region
# 0  United States  32669121.0  584226.0  North America
# 1          India  16257309.0  186928.0           Asia

# %%
df1.columns=df1.columns.str.upper()  

#.upper() to change header to uppercase 

df1.head(2)
# Out:
#          COUNTRY       CASES    DEATHS         REGION
# 0  United States  32669121.0  584226.0  North America
# 1          India  16257309.0  186928.0           Asia

# %%
df1.shape
# Out:
# (220, 4)

# %%
df.shape
# Out:
# (20, 6)

# %% [markdown]
# ## Merge

# %% [markdown]
# Pandas provides a single function, merge(), as the entry point for all standard database join operations between DataFrame or named Series objects.
#
# **MERGE** combining data on common columns or indices.
#
# You can achieve both many-to-one and many-to-many joins with merge()

# %% [markdown]
# ![Mergeconcept](https://files.realpython.com/media/join_diagram.93e6ef63afbe.png)

# %% [markdown]
# When gluing together multiple DataFrames, you have a choice of how to handle the other axes (other than the one being concatenated). This can be done in the following two ways

# %% [markdown]
# Take the union of them all, join='outer'. This is the default option as it results in zero information loss.
#
# Take the intersection, join='inner'.

# %%
merge_df=pd.merge(df, df1)
merge_df
# Out:
#        COUNTRY  POPULATION      AREA       GDP CONTINENTS     IND_DAY  \
# 0        China     1398.72   9596.96  12234.78       Asia         NaN
# 1        India     1351.16   3287.26   2575.67       Asia   15/8/1947
# 2    Indonesia      268.07   1910.93   1015.54       Asia   17/8/1945
# 3       Brazil      210.32   8515.77   2055.51  S.America  1822-09-07
# 4     Pakistan      205.71    881.91    302.14       Asia   14/8/1947
# 5      Nigeria      200.96    923.77    375.77     Africa   1/10/1960
# 6   Bangladesh      167.09    147.57    245.63       Asia   26/3/1971
# 7       Russia      146.79  17098.25   1530.75        NaN   12/6/1992
# 8       Mexico      126.58   1964.38   1158.23  N.America  1810-09-16
# 9        Japan      126.22    377.97   4872.42       Asia         NaN
# 10     Germany       83.02    357.11   3693.20     Europe         NaN
# 11      France       67.02    640.68   2582.49     Europe  1789-07-14
# 12       Italy       60.36    301.34   1943.84     Europe         NaN
# 13   Argentina       44.94   2780.40    637.49  S.America  1816-07-09
# 14     Algeria       43.38   2381.74    167.56     Africa    5/7/1962
# 15      Canada       37.59   9984.67   1647.12  N.America  1867-07-01
# 16   Australia       25.47   7692.02   1408.68    Oceania         NaN
# 17  Kazakhstan       18.53   2724.90    159.41       Asia  16/12/1991
#
#          CASES    DEATHS             REGION
# 0      90566.0    4636.0               Asia
# 1   16257309.0  186928.0               Asia
# 2    1626812.0   44172.0               Asia
# 3   14172139.0  383757.0      South America
# 4     784108.0   16842.0               Asia
# 5     164588.0    2061.0             Africa
# 6     736074.0   10781.0               Asia
# 7    4736121.0  107103.0             Europe
# 8    2319519.0  214095.0      North America
# 9     547137.0    9777.0               Asia
# 10   3238054.0   81693.0             Europe
# 11   5408606.0  102164.0             Europe
# 12   3920945.0  118357.0             Europe
# 13   2796768.0   60620.0      South America
# 14    120363.0    3181.0             Africa
# 15   1155834.0   23822.0      North America
# 16     29626.0     910.0  Australia/Oceania
# 17    300733.0    3512.0               Asia

# %% [markdown]
# By default, how = inner, which will merge only match data.

# %%
merge_df.shape
# Out:
# (18, 9)

# %%
merge_df.CONTINENTS=merge_df.CONTINENTS.replace(['N.America','S.America'],['North America','South America'])
merge_df
# Out:
#        COUNTRY  POPULATION      AREA       GDP     CONTINENTS     IND_DAY  \
# 0        China     1398.72   9596.96  12234.78           Asia         NaN
# 1        India     1351.16   3287.26   2575.67           Asia   15/8/1947
# 2    Indonesia      268.07   1910.93   1015.54           Asia   17/8/1945
# 3       Brazil      210.32   8515.77   2055.51  South America  1822-09-07
# 4     Pakistan      205.71    881.91    302.14           Asia   14/8/1947
# 5      Nigeria      200.96    923.77    375.77         Africa   1/10/1960
# 6   Bangladesh      167.09    147.57    245.63           Asia   26/3/1971
# 7       Russia      146.79  17098.25   1530.75            NaN   12/6/1992
# 8       Mexico      126.58   1964.38   1158.23  North America  1810-09-16
# 9        Japan      126.22    377.97   4872.42           Asia         NaN
# 10     Germany       83.02    357.11   3693.20         Europe         NaN
# 11      France       67.02    640.68   2582.49         Europe  1789-07-14
# 12       Italy       60.36    301.34   1943.84         Europe         NaN
# 13   Argentina       44.94   2780.40    637.49  South America  1816-07-09
# 14     Algeria       43.38   2381.74    167.56         Africa    5/7/1962
# 15      Canada       37.59   9984.67   1647.12  North America  1867-07-01
# 16   Australia       25.47   7692.02   1408.68        Oceania         NaN
# 17  Kazakhstan       18.53   2724.90    159.41           Asia  16/12/1991
#
#          CASES    DEATHS             REGION
# 0      90566.0    4636.0               Asia
# 1   16257309.0  186928.0               Asia
# 2    1626812.0   44172.0               Asia
# 3   14172139.0  383757.0      South America
# 4     784108.0   16842.0               Asia
# 5     164588.0    2061.0             Africa
# 6     736074.0   10781.0               Asia
# 7    4736121.0  107103.0             Europe
# 8    2319519.0  214095.0      North America
# 9     547137.0    9777.0               Asia
# 10   3238054.0   81693.0             Europe
# 11   5408606.0  102164.0             Europe
# 12   3920945.0  118357.0             Europe
# 13   2796768.0   60620.0      South America
# 14    120363.0    3181.0             Africa
# 15   1155834.0   23822.0      North America
# 16     29626.0     910.0  Australia/Oceania
# 17    300733.0    3512.0               Asia

# %%
test1merge_df=pd.merge(df, df1, how='inner')
test1merge_df
# Out:
#        COUNTRY  POPULATION      AREA       GDP CONTINENTS     IND_DAY  \
# 0        China     1398.72   9596.96  12234.78       Asia         NaN
# 1        India     1351.16   3287.26   2575.67       Asia   15/8/1947
# 2    Indonesia      268.07   1910.93   1015.54       Asia   17/8/1945
# 3       Brazil      210.32   8515.77   2055.51  S.America  1822-09-07
# 4     Pakistan      205.71    881.91    302.14       Asia   14/8/1947
# 5      Nigeria      200.96    923.77    375.77     Africa   1/10/1960
# 6   Bangladesh      167.09    147.57    245.63       Asia   26/3/1971
# 7       Russia      146.79  17098.25   1530.75        NaN   12/6/1992
# 8       Mexico      126.58   1964.38   1158.23  N.America  1810-09-16
# 9        Japan      126.22    377.97   4872.42       Asia         NaN
# 10     Germany       83.02    357.11   3693.20     Europe         NaN
# 11      France       67.02    640.68   2582.49     Europe  1789-07-14
# 12       Italy       60.36    301.34   1943.84     Europe         NaN
# 13   Argentina       44.94   2780.40    637.49  S.America  1816-07-09
# 14     Algeria       43.38   2381.74    167.56     Africa    5/7/1962
# 15      Canada       37.59   9984.67   1647.12  N.America  1867-07-01
# 16   Australia       25.47   7692.02   1408.68    Oceania         NaN
# 17  Kazakhstan       18.53   2724.90    159.41       Asia  16/12/1991
#
#          CASES    DEATHS             REGION
# 0      90566.0    4636.0               Asia
# 1   16257309.0  186928.0               Asia
# 2    1626812.0   44172.0               Asia
# 3   14172139.0  383757.0      South America
# 4     784108.0   16842.0               Asia
# 5     164588.0    2061.0             Africa
# 6     736074.0   10781.0               Asia
# 7    4736121.0  107103.0             Europe
# 8    2319519.0  214095.0      North America
# 9     547137.0    9777.0               Asia
# 10   3238054.0   81693.0             Europe
# 11   5408606.0  102164.0             Europe
# 12   3920945.0  118357.0             Europe
# 13   2796768.0   60620.0      South America
# 14    120363.0    3181.0             Africa
# 15   1155834.0   23822.0      North America
# 16     29626.0     910.0  Australia/Oceania
# 17    300733.0    3512.0               Asia

# %%
test1merge_df.shape
# Out:
# (18, 9)

# %%
merge_df=pd.merge(df, df1, how='outer')
merge_df
# will merge all data
# Out:
#               COUNTRY  POPULATION     AREA       GDP CONTINENTS     IND_DAY  \
# 0               China     1398.72  9596.96  12234.78       Asia         NaN
# 1               India     1351.16  3287.26   2575.67       Asia   15/8/1947
# 2                  US      329.74  9833.52  19485.39  N.America  1776-07-04
# 3           Indonesia      268.07  1910.93   1015.54       Asia   17/8/1945
# 4              Brazil      210.32  8515.77   2055.51  S.America  1822-09-07
# ..                ...         ...      ...       ...        ...         ...
# 217        MS Zaandam         NaN      NaN       NaN        NaN         NaN
# 218           Vanuatu         NaN      NaN       NaN        NaN         NaN
# 219  Marshall Islands         NaN      NaN       NaN        NaN         NaN
# 220             Samoa         NaN      NaN       NaN        NaN         NaN
# 221        Micronesia         NaN      NaN       NaN        NaN         NaN
#
#           CASES    DEATHS             REGION
# 0       90566.0    4636.0               Asia
# 1    16257309.0  186928.0               Asia
# 2           NaN       NaN                NaN
# 3     1626812.0   44172.0               Asia
# 4    14172139.0  383757.0      South America
# ..          ...       ...                ...
# 217         9.0       2.0                NaN
# 218         4.0       1.0  Australia/Oceania
# 219         4.0       0.0  Australia/Oceania
# 220         3.0       0.0  Australia/Oceania
# 221         1.0       0.0  Australia/Oceania
#
# [222 rows x 9 columns]

# %%
merge_df.shape
# Out:
# (222, 9)

# %%
# Let's try how='left' or 'right'

test1=pd.merge(df, df1, how='left')
test1
# Out:
#        COUNTRY  POPULATION      AREA       GDP CONTINENTS     IND_DAY  \
# 0        China     1398.72   9596.96  12234.78       Asia         NaN
# 1        India     1351.16   3287.26   2575.67       Asia   15/8/1947
# 2           US      329.74   9833.52  19485.39  N.America  1776-07-04
# 3    Indonesia      268.07   1910.93   1015.54       Asia   17/8/1945
# 4       Brazil      210.32   8515.77   2055.51  S.America  1822-09-07
# 5     Pakistan      205.71    881.91    302.14       Asia   14/8/1947
# 6      Nigeria      200.96    923.77    375.77     Africa   1/10/1960
# 7   Bangladesh      167.09    147.57    245.63       Asia   26/3/1971
# 8       Russia      146.79  17098.25   1530.75        NaN   12/6/1992
# 9       Mexico      126.58   1964.38   1158.23  N.America  1810-09-16
# 10       Japan      126.22    377.97   4872.42       Asia         NaN
# 11     Germany       83.02    357.11   3693.20     Europe         NaN
# 12      France       67.02    640.68   2582.49     Europe  1789-07-14
# 13          UK       66.44    242.50   2631.23     Europe         NaN
# 14       Italy       60.36    301.34   1943.84     Europe         NaN
# 15   Argentina       44.94   2780.40    637.49  S.America  1816-07-09
# 16     Algeria       43.38   2381.74    167.56     Africa    5/7/1962
# 17      Canada       37.59   9984.67   1647.12  N.America  1867-07-01
# 18   Australia       25.47   7692.02   1408.68    Oceania         NaN
# 19  Kazakhstan       18.53   2724.90    159.41       Asia  16/12/1991
#
#          CASES    DEATHS             REGION
# 0      90566.0    4636.0               Asia
# 1   16257309.0  186928.0               Asia
# 2          NaN       NaN                NaN
# 3    1626812.0   44172.0               Asia
# 4   14172139.0  383757.0      South America
# 5     784108.0   16842.0               Asia
# 6     164588.0    2061.0             Africa
# 7     736074.0   10781.0               Asia
# 8    4736121.0  107103.0             Europe
# 9    2319519.0  214095.0      North America
# 10    547137.0    9777.0               Asia
# 11   3238054.0   81693.0             Europe
# 12   5408606.0  102164.0             Europe
# 13         NaN       NaN                NaN
# 14   3920945.0  118357.0             Europe
# 15   2796768.0   60620.0      South America
# 16    120363.0    3181.0             Africa
# 17   1155834.0   23822.0      North America
# 18     29626.0     910.0  Australia/Oceania
# 19    300733.0    3512.0               Asia

# %% [markdown]
# how='left', will merge base on left file, in this example is df

# %%
test2=pd.merge(df, df1, how='right')
test2
# Out:
#               COUNTRY  POPULATION      AREA      GDP CONTINENTS     IND_DAY  \
# 0       United States         NaN       NaN      NaN        NaN         NaN
# 1               India     1351.16   3287.26  2575.67       Asia   15/8/1947
# 2              Brazil      210.32   8515.77  2055.51  S.America  1822-09-07
# 3              France       67.02    640.68  2582.49     Europe  1789-07-14
# 4              Russia      146.79  17098.25  1530.75        NaN   12/6/1992
# ..                ...         ...       ...      ...        ...         ...
# 215        MS Zaandam         NaN       NaN      NaN        NaN         NaN
# 216           Vanuatu         NaN       NaN      NaN        NaN         NaN
# 217  Marshall Islands         NaN       NaN      NaN        NaN         NaN
# 218             Samoa         NaN       NaN      NaN        NaN         NaN
# 219        Micronesia         NaN       NaN      NaN        NaN         NaN
#
#           CASES    DEATHS             REGION
# 0    32669121.0  584226.0      North America
# 1    16257309.0  186928.0               Asia
# 2    14172139.0  383757.0      South America
# 3     5408606.0  102164.0             Europe
# 4     4736121.0  107103.0             Europe
# ..          ...       ...                ...
# 215         9.0       2.0                NaN
# 216         4.0       1.0  Australia/Oceania
# 217         4.0       0.0  Australia/Oceania
# 218         3.0       0.0  Australia/Oceania
# 219         1.0       0.0  Australia/Oceania
#
# [220 rows x 9 columns]

# %% [markdown]
# how='right', will merge base on right file, in this example is df1

# %% [markdown]
# ## Concatenating

# %% [markdown]
# With concatenation, your datasets are just stitched together along an axis — either the row axis or column axis.

# %%
concat_df=pd.concat([df, df1], axis=1)
concat_df
# Out:
#        COUNTRY  POPULATION     AREA       GDP CONTINENTS     IND_DAY  \
# 0        China     1398.72  9596.96  12234.78       Asia         NaN
# 1        India     1351.16  3287.26   2575.67       Asia   15/8/1947
# 2           US      329.74  9833.52  19485.39  N.America  1776-07-04
# 3    Indonesia      268.07  1910.93   1015.54       Asia   17/8/1945
# 4       Brazil      210.32  8515.77   2055.51  S.America  1822-09-07
# ..         ...         ...      ...       ...        ...         ...
# 215        NaN         NaN      NaN       NaN        NaN         NaN
# 216        NaN         NaN      NaN       NaN        NaN         NaN
# 217        NaN         NaN      NaN       NaN        NaN         NaN
# 218        NaN         NaN      NaN       NaN        NaN         NaN
# 219        NaN         NaN      NaN       NaN        NaN         NaN
#
#               COUNTRY       CASES    DEATHS             REGION
# 0       United States  32669121.0  584226.0      North America
# 1               India  16257309.0  186928.0               Asia
# 2              Brazil  14172139.0  383757.0      South America
# 3              France   5408606.0  102164.0             Europe
# 4              Russia   4736121.0  107103.0             Europe
# ..                ...         ...       ...                ...
# 215        MS Zaandam         9.0       2.0                NaN
# 216           Vanuatu         4.0       1.0  Australia/Oceania
# 217  Marshall Islands         4.0       0.0  Australia/Oceania
# 218             Samoa         3.0       0.0  Australia/Oceania
# 219        Micronesia         1.0       0.0  Australia/Oceania
#
# [220 rows x 10 columns]

# %% [markdown]
# Let's try append the data

# %% [markdown]
# Let's call add new dataset call data4

# %%
from google.colab import files
data_to_load = files.upload()

# %%
import io
df2 = pd.read_csv(io.BytesIO(data_to_load['data4.csv']))
df2

# %%
# if using directly from python or jupyter notebook
df2 = pd.read_csv('data4.csv')
df2
# Out:
#    COUNTRY  POPULATION    AREA     GDP CONTINENTS     IND_DAY
# 0    Egypt          93  640.68  375.77       Asia  1867-07-01
# 1  Germany          81  242.50  245.63     Europe  1789-07-14
# 2     Iran          80  301.34  143.00     Europe         NaN
# 3   Turkey          79     NaN  250.00        NaN         NaN

# %%
test3 = df.append(df2, ignore_index=True, sort=False)
test3
# Out:
#        COUNTRY  POPULATION      AREA       GDP CONTINENTS     IND_DAY
# 0        China     1398.72   9596.96  12234.78       Asia         NaN
# 1        India     1351.16   3287.26   2575.67       Asia   15/8/1947
# 2           US      329.74   9833.52  19485.39  N.America  1776-07-04
# 3    Indonesia      268.07   1910.93   1015.54       Asia   17/8/1945
# 4       Brazil      210.32   8515.77   2055.51  S.America  1822-09-07
# 5     Pakistan      205.71    881.91    302.14       Asia   14/8/1947
# 6      Nigeria      200.96    923.77    375.77     Africa   1/10/1960
# 7   Bangladesh      167.09    147.57    245.63       Asia   26/3/1971
# 8       Russia      146.79  17098.25   1530.75        NaN   12/6/1992
# 9       Mexico      126.58   1964.38   1158.23  N.America  1810-09-16
# 10       Japan      126.22    377.97   4872.42       Asia         NaN
# 11     Germany       83.02    357.11   3693.20     Europe         NaN
# 12      France       67.02    640.68   2582.49     Europe  1789-07-14
# 13          UK       66.44    242.50   2631.23     Europe         NaN
# 14       Italy       60.36    301.34   1943.84     Europe         NaN
# 15   Argentina       44.94   2780.40    637.49  S.America  1816-07-09
# 16     Algeria       43.38   2381.74    167.56     Africa    5/7/1962
# 17      Canada       37.59   9984.67   1647.12  N.America  1867-07-01
# 18   Australia       25.47   7692.02   1408.68    Oceania         NaN
# 19  Kazakhstan       18.53   2724.90    159.41       Asia  16/12/1991
# 20       Egypt       93.00    640.68    375.77       Asia  1867-07-01
# 21     Germany       81.00    242.50    245.63     Europe  1789-07-14
# 22        Iran       80.00    301.34    143.00     Europe         NaN
# 23      Turkey       79.00       NaN    250.00        NaN         NaN

# %% [markdown]
# data from df 1 and data 4 are combine at row level

# %% [markdown]
# **LET'S MOVE TO GROUPBY**

# %%
df.head(2)
# Out:
#   COUNTRY  POPULATION     AREA       GDP CONTINENTS    IND_DAY
# 0   China     1398.72  9596.96  12234.78       Asia        NaN
# 1   India     1351.16  3287.26   2575.67       Asia  15/8/1947

# %%
df1.head(2)
# Out:
#          COUNTRY       CASES    DEATHS         REGION
# 0  United States  32669121.0  584226.0  North America
# 1          India  16257309.0  186928.0           Asia

# %%
df2.head()
# Out:
#    COUNTRY  POPULATION    AREA     GDP CONTINENTS     IND_DAY
# 0    Egypt          93  640.68  375.77       Asia  1867-07-01
# 1  Germany          81  242.50  245.63     Europe  1789-07-14
# 2     Iran          80  301.34  143.00     Europe         NaN
# 3   Turkey          79     NaN  250.00        NaN         NaN

# %%
merge_df.head()
# Out:
#      COUNTRY  POPULATION     AREA       GDP CONTINENTS     IND_DAY  \
# 0      China     1398.72  9596.96  12234.78       Asia         NaN
# 1      India     1351.16  3287.26   2575.67       Asia   15/8/1947
# 2         US      329.74  9833.52  19485.39  N.America  1776-07-04
# 3  Indonesia      268.07  1910.93   1015.54       Asia   17/8/1945
# 4     Brazil      210.32  8515.77   2055.51  S.America  1822-09-07
#
#         CASES    DEATHS         REGION
# 0     90566.0    4636.0           Asia
# 1  16257309.0  186928.0           Asia
# 2         NaN       NaN            NaN
# 3   1626812.0   44172.0           Asia
# 4  14172139.0  383757.0  South America

# %%
merge_df.shape
# Out:
# (222, 9)

# %%
merge_df.dtypes
# Out:
# COUNTRY        object
# POPULATION    float64
# AREA          float64
# GDP           float64
# CONTINENTS     object
# IND_DAY        object
# CASES         float64
# DEATHS        float64
# REGION         object
# dtype: object

# %% [markdown]
# **CONTINENT and REGION actually referring to the same thing.**
# Let's try to fix it

# %% [markdown]
# Checking the elements

# %%
reg=merge_df.groupby('REGION').sum()
reg
# Out:
#                    POPULATION      AREA       GDP       CASES    DEATHS
# REGION
# Africa                 244.34   3305.51    543.33   4513248.0  119538.0
# Asia                  3535.50  18927.50  21405.59  35616438.0  482532.0
# Australia/Oceania       25.47   7692.02   1408.68     61971.0    1184.0
# Europe                 357.19  18397.38   9750.28  43483441.0  989869.0
# North America          164.17  11949.05   2805.35  37760260.0  852502.0
# South America          255.26  11296.17   2693.00  23897427.0  639607.0

# %%
con=merge_df.groupby('CONTINENTS').sum()
con
# Out:
#             POPULATION      AREA       GDP       CASES    DEATHS
# CONTINENTS
# Africa          244.34   3305.51    543.33    284951.0    5242.0
# Asia           3535.50  18927.50  21405.59  20342739.0  276648.0
# Europe          276.84   1541.63  10850.76  12567605.0  302214.0
# N.America       493.91  21782.57  22290.74   3475353.0  237917.0
# Oceania          25.47   7692.02   1408.68     29626.0     910.0
# S.America       255.26  11296.17   2693.00  16968907.0  444377.0

# %%
merge_df.CONTINENTS=merge_df.CONTINENTS.replace(['N.America','S.America'],['North America','South America'])
merge_df
# Out:
#               COUNTRY  POPULATION     AREA       GDP     CONTINENTS  \
# 0               China     1398.72  9596.96  12234.78           Asia
# 1               India     1351.16  3287.26   2575.67           Asia
# 2                  US      329.74  9833.52  19485.39  North America
# 3           Indonesia      268.07  1910.93   1015.54           Asia
# 4              Brazil      210.32  8515.77   2055.51  South America
# ..                ...         ...      ...       ...            ...
# 217        MS Zaandam         NaN      NaN       NaN            NaN
# 218           Vanuatu         NaN      NaN       NaN            NaN
# 219  Marshall Islands         NaN      NaN       NaN            NaN
# 220             Samoa         NaN      NaN       NaN            NaN
# 221        Micronesia         NaN      NaN       NaN            NaN
#
#         IND_DAY       CASES    DEATHS             REGION
# 0           NaN     90566.0    4636.0               Asia
# 1     15/8/1947  16257309.0  186928.0               Asia
# 2    1776-07-04         NaN       NaN                NaN
# 3     17/8/1945   1626812.0   44172.0               Asia
# 4    1822-09-07  14172139.0  383757.0      South America
# ..          ...         ...       ...                ...
# 217         NaN         9.0       2.0                NaN
# 218         NaN         4.0       1.0  Australia/Oceania
# 219         NaN         4.0       0.0  Australia/Oceania
# 220         NaN         3.0       0.0  Australia/Oceania
# 221         NaN         1.0       0.0  Australia/Oceania
#
# [222 rows x 9 columns]

# %%
reg=merge_df.groupby('REGION').sum()
reg
# Out:
#                    POPULATION      AREA       GDP       CASES    DEATHS
# REGION
# Africa                 244.34   3305.51    543.33   4513248.0  119538.0
# Asia                  3535.50  18927.50  21405.59  35616438.0  482532.0
# Australia/Oceania       25.47   7692.02   1408.68     61971.0    1184.0
# Europe                 357.19  18397.38   9750.28  43483441.0  989869.0
# North America          164.17  11949.05   2805.35  37760260.0  852502.0
# South America          255.26  11296.17   2693.00  23897427.0  639607.0

# %%
con=merge_df.groupby('CONTINENTS').sum()
con
# Out:
#                POPULATION      AREA       GDP       CASES    DEATHS
# CONTINENTS
# Africa             244.34   3305.51    543.33    284951.0    5242.0
# Asia              3535.50  18927.50  21405.59  20342739.0  276648.0
# Europe             276.84   1541.63  10850.76  12567605.0  302214.0
# North America      493.91  21782.57  22290.74   3475353.0  237917.0
# Oceania             25.47   7692.02   1408.68     29626.0     910.0
# South America      255.26  11296.17   2693.00  16968907.0  444377.0

# %%
df = df.rename(columns={'CONTINENTS': 'REGION'})
df.head()
# Out:
#      COUNTRY  POPULATION     AREA       GDP     REGION     IND_DAY
# 0      China     1398.72  9596.96  12234.78       Asia         NaN
# 1      India     1351.16  3287.26   2575.67       Asia   15/8/1947
# 2         US      329.74  9833.52  19485.39  N.America  1776-07-04
# 3  Indonesia      268.07  1910.93   1015.54       Asia   17/8/1945
# 4     Brazil      210.32  8515.77   2055.51  S.America  1822-09-07

# %%
df1.head()
# Out:
#          COUNTRY       CASES    DEATHS         REGION
# 0  United States  32669121.0  584226.0  North America
# 1          India  16257309.0  186928.0           Asia
# 2         Brazil  14172139.0  383757.0  South America
# 3         France   5408606.0  102164.0         Europe
# 4         Russia   4736121.0  107103.0         Europe

# %%
df101=pd.merge(df, df1)
df101
# Out:
#        COUNTRY  POPULATION     AREA       GDP  REGION     IND_DAY       CASES  \
# 0        China     1398.72  9596.96  12234.78    Asia         NaN     90566.0
# 1        India     1351.16  3287.26   2575.67    Asia   15/8/1947  16257309.0
# 2    Indonesia      268.07  1910.93   1015.54    Asia   17/8/1945   1626812.0
# 3     Pakistan      205.71   881.91    302.14    Asia   14/8/1947    784108.0
# 4      Nigeria      200.96   923.77    375.77  Africa   1/10/1960    164588.0
# 5   Bangladesh      167.09   147.57    245.63    Asia   26/3/1971    736074.0
# 6        Japan      126.22   377.97   4872.42    Asia         NaN    547137.0
# 7      Germany       83.02   357.11   3693.20  Europe         NaN   3238054.0
# 8       France       67.02   640.68   2582.49  Europe  1789-07-14   5408606.0
# 9        Italy       60.36   301.34   1943.84  Europe         NaN   3920945.0
# 10     Algeria       43.38  2381.74    167.56  Africa    5/7/1962    120363.0
# 11  Kazakhstan       18.53  2724.90    159.41    Asia  16/12/1991    300733.0
#
#       DEATHS
# 0     4636.0
# 1   186928.0
# 2    44172.0
# 3    16842.0
# 4     2061.0
# 5    10781.0
# 6     9777.0
# 7    81693.0
# 8   102164.0
# 9   118357.0
# 10    3181.0
# 11    3512.0

# %%
reg=df101.groupby('REGION').sum()
reg
# Out:
#         POPULATION      AREA       GDP       CASES    DEATHS
# REGION
# Africa      244.34   3305.51    543.33    284951.0    5242.0
# Asia       3535.50  18927.50  21405.59  20342739.0  276648.0
# Europe      210.40   1299.13   8219.53  12567605.0  302214.0

# %% [markdown]
# **What if you want to group the data into range or scale**

# %% [markdown]
# **Data binning** <br>
# 1) Data binning (or bucketing) groups data in bins (or buckets), in the sense that it replaces values contained into a small interval with a single representative value for that interval.<br>
# 2) Binning can be applied to convert numeric values to categorical or to sample (quantise) numeric values

# %% [markdown]
# For example, we want to group GDP in df into this group

# %% [markdown]
# ![income_group.PNG](attachment:income_group.PNG)

# %% [markdown]
# we can use pd.cut

# %%
# ?pd.cut

# %% [markdown]
# Can we use this way?

# %%
bins=np.linspace(min(df["GDP"]),max (df["GDP"]),5) # regroup to 4 income group
group=["Low Income","Middle Low Income","Upper Middle Income", "High Income" ]
df["gdp_bin"]=pd.cut(df["GDP"],bins,labels=group,include_lowest=True)

# %% [markdown]
# What will happen to your df?

# %%
df
# Out:
#        COUNTRY  POPULATION      AREA       GDP     REGION     IND_DAY  \
# 0        China     1398.72   9596.96  12234.78       Asia         NaN
# 1        India     1351.16   3287.26   2575.67       Asia   15/8/1947
# 2           US      329.74   9833.52  19485.39  N.America  1776-07-04
# 3    Indonesia      268.07   1910.93   1015.54       Asia   17/8/1945
# 4       Brazil      210.32   8515.77   2055.51  S.America  1822-09-07
# 5     Pakistan      205.71    881.91    302.14       Asia   14/8/1947
# 6      Nigeria      200.96    923.77    375.77     Africa   1/10/1960
# 7   Bangladesh      167.09    147.57    245.63       Asia   26/3/1971
# 8       Russia      146.79  17098.25   1530.75        NaN   12/6/1992
# 9       Mexico      126.58   1964.38   1158.23  N.America  1810-09-16
# 10       Japan      126.22    377.97   4872.42       Asia         NaN
# 11     Germany       83.02    357.11   3693.20     Europe         NaN
# 12      France       67.02    640.68   2582.49     Europe  1789-07-14
# 13          UK       66.44    242.50   2631.23     Europe         NaN
# 14       Italy       60.36    301.34   1943.84     Europe         NaN
# 15   Argentina       44.94   2780.40    637.49  S.America  1816-07-09
# 16     Algeria       43.38   2381.74    167.56     Africa    5/7/1962
# 17      Canada       37.59   9984.67   1647.12  N.America  1867-07-01
# 18   Australia       25.47   7692.02   1408.68    Oceania         NaN
# 19  Kazakhstan       18.53   2724.90    159.41       Asia  16/12/1991
#
#                 gdp_bin
# 0   Upper Middle Income
# 1            Low Income
# 2           High Income
# 3            Low Income
# 4            Low Income
# 5            Low Income
# 6            Low Income
# 7            Low Income
# 8            Low Income
# 9            Low Income
# 10           Low Income
# 11           Low Income
# 12           Low Income
# 13           Low Income
# 14           Low Income
# 15           Low Income
# 16           Low Income
# 17           Low Income
# 18           Low Income
# 19           Low Income

# %%
df['GDP'].min()
# Out:
# 159.41

# %%
df['GDP'].max()
# Out:
# 19485.39

# %% [markdown]
# Let's make some changes

# %%
df["GDP_GROUP"]=pd.cut(df['GDP'], bins=[-float("inf"), 1036, 4045, 12535, float("inf")], 
                          labels=['Low income', 'Lower-middle income', 'Upper-middle income', 'High income'])

# %%
df.head()
# Out:
#      COUNTRY  POPULATION     AREA       GDP     REGION     IND_DAY  \
# 0      China     1398.72  9596.96  12234.78       Asia         NaN
# 1      India     1351.16  3287.26   2575.67       Asia   15/8/1947
# 2         US      329.74  9833.52  19485.39  N.America  1776-07-04
# 3  Indonesia      268.07  1910.93   1015.54       Asia   17/8/1945
# 4     Brazil      210.32  8515.77   2055.51  S.America  1822-09-07
#
#                gdp_bin            GDP_GROUP
# 0  Upper Middle Income  Upper-middle income
# 1           Low Income  Lower-middle income
# 2          High Income          High income
# 3           Low Income           Low income
# 4           Low Income  Lower-middle income

# %%
df["GDP_RANGE"]=pd.cut(df['GDP'], bins=[-float("inf"), 1036, 4045, 12535, float("inf")], 
                       labels=['< 1,036', '1,036 - 4,045', '4,046 - 12,535', '> 12,535'])

# %%
df.head()
# Out:
#      COUNTRY  POPULATION     AREA       GDP     REGION     IND_DAY  \
# 0      China     1398.72  9596.96  12234.78       Asia         NaN
# 1      India     1351.16  3287.26   2575.67       Asia   15/8/1947
# 2         US      329.74  9833.52  19485.39  N.America  1776-07-04
# 3  Indonesia      268.07  1910.93   1015.54       Asia   17/8/1945
# 4     Brazil      210.32  8515.77   2055.51  S.America  1822-09-07
#
#                gdp_bin            GDP_GROUP       GDP_RANGE
# 0  Upper Middle Income  Upper-middle income  4,046 - 12,535
# 1           Low Income  Lower-middle income   1,036 - 4,045
# 2          High Income          High income        > 12,535
# 3           Low Income           Low income         < 1,036
# 4           Low Income  Lower-middle income   1,036 - 4,045

# %% [markdown]
# Not a fan of pandas? Want to try something else?

# %%
def group(gincome):
    if gincome >= 12535:
        return "high income"
    if 4046 < gincome < 12535:
        return "upper-middle income"
    if 1036 < gincome < 4045:
        return "lower-middle income"
    if gincome <= 1036:
        return "low income"
    else:
        return 0
    
df['group'] = df['GDP'].apply(group)
df
# Out:
#        COUNTRY  POPULATION      AREA       GDP     REGION     IND_DAY  \
# 0        China     1398.72   9596.96  12234.78       Asia         NaN
# 1        India     1351.16   3287.26   2575.67       Asia   15/8/1947
# 2           US      329.74   9833.52  19485.39  N.America  1776-07-04
# 3    Indonesia      268.07   1910.93   1015.54       Asia   17/8/1945
# 4       Brazil      210.32   8515.77   2055.51  S.America  1822-09-07
# 5     Pakistan      205.71    881.91    302.14       Asia   14/8/1947
# 6      Nigeria      200.96    923.77    375.77     Africa   1/10/1960
# 7   Bangladesh      167.09    147.57    245.63       Asia   26/3/1971
# 8       Russia      146.79  17098.25   1530.75        NaN   12/6/1992
# 9       Mexico      126.58   1964.38   1158.23  N.America  1810-09-16
# 10       Japan      126.22    377.97   4872.42       Asia         NaN
# 11     Germany       83.02    357.11   3693.20     Europe         NaN
# 12      France       67.02    640.68   2582.49     Europe  1789-07-14
# 13          UK       66.44    242.50   2631.23     Europe         NaN
# 14       Italy       60.36    301.34   1943.84     Europe         NaN
# 15   Argentina       44.94   2780.40    637.49  S.America  1816-07-09
# 16     Algeria       43.38   2381.74    167.56     Africa    5/7/1962
# 17      Canada       37.59   9984.67   1647.12  N.America  1867-07-01
# 18   Australia       25.47   7692.02   1408.68    Oceania         NaN
# 19  Kazakhstan       18.53   2724.90    159.41       Asia  16/12/1991
#
#                 gdp_bin            GDP_GROUP       GDP_RANGE  \
# 0   Upper Middle Income  Upper-middle income  4,046 - 12,535
# 1            Low Income  Lower-middle income   1,036 - 4,045
# 2           High Income          High income        > 12,535
# 3            Low Income           Low income         < 1,036
# 4            Low Income  Lower-middle income   1,036 - 4,045
# 5            Low Income           Low income         < 1,036
# 6            Low Income           Low income         < 1,036
# 7            Low Income           Low income         < 1,036
# 8            Low Income  Lower-middle income   1,036 - 4,045
# 9            Low Income  Lower-middle income   1,036 - 4,045
# 10           Low Income  Upper-middle income  4,046 - 12,535
# 11           Low Income  Lower-middle income   1,036 - 4,045
# 12           Low Income  Lower-middle income   1,036 - 4,045
# 13           Low Income  Lower-middle income   1,036 - 4,045
# 14           Low Income  Lower-middle income   1,036 - 4,045
# 15           Low Income           Low income         < 1,036
# 16           Low Income           Low income         < 1,036
# 17           Low Income  Lower-middle income   1,036 - 4,045
# 18           Low Income  Lower-middle income   1,036 - 4,045
# 19           Low Income           Low income         < 1,036
#
#                   group
# 0   upper-middle income
# 1   lower-middle income
# 2           high income
# 3            low income
# 4   lower-middle income
# 5            low income
# 6            low income
# 7            low income
# 8   lower-middle income
# 9   lower-middle income
# 10  upper-middle income
# 11  lower-middle income
# 12  lower-middle income
# 13  lower-middle income
# 14  lower-middle income
# 15           low income
# 16           low income
# 17  lower-middle income
# 18  lower-middle income
# 19           low income

# %% [markdown]
# There are many ways for us to get answers. <br>
# What matters is we know what we want to do. No need to worry about how to do it. <br>

# %% [markdown]
# By the way, we don't want gdp_bin and group column right?

# %% [markdown]
# How to remove it?

# %% [markdown]
# Check your previous note.

# %% [markdown]
# **End of part 1**<br>
#
# I hope you learn something usefull today.<br>
#
# Thank you.

# %% [markdown]
# **Prepared by** <br>
# Nur Hurriyatul Huda Abdullah Sani (nurhuda@dosm.gov.my)

# %% [markdown]
# **For more references**, please visit <br>
# https://coreteambda.wixsite.com/blog/learn-and-lead

# %% [markdown]
# References:<br>
# [1] https://stackoverflow.com/questions/42818262/pandas-dataframe-replace-nat-with-none<br>
# [2] https://pandas.pydata.org/pandas-docs/stable/user_guide/timedeltas.html<br>
# [3] https://stackoverflow.com/questions/32327314/how-to-rearrange-a-date-in-python <br>
# [4] https://stackoverflow.com/questions/30127427/pandas-cut-with-infinite-upper-lower-bounds
