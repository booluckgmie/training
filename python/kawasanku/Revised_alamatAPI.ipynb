# %% [markdown]
# <a href="https://colab.research.google.com/github/booluckgmie/training/blob/main/Revised_alamatAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pcode = pd.read_csv("https://raw.githubusercontent.com/booluckgmie/training/main/python/kawasanku/poskodM_2020.csv", dtype={'Postcode':str})
# pcode.drop(pcode.columns[0], axis=1, inplace=True)
pcode.head()
# Out:
#                                   Location Postcode      Post_Office  State  \
# 0                           Estuari Garden    79000  Iskandar Puteri  Johor
# 1               Kota Ilmu Educity@Iskandar    79000  Iskandar Puteri  Johor
# 2                            Laman Estuari    79000  Iskandar Puteri  Johor
# 3  Pusat Pentadbiran Kerajaan Negeri Johor    79000  Iskandar Puteri  Johor
# 4                           Puteri Harbour    79000  Iskandar Puteri  Johor
#
#         DateUpdate
# 0  10/11/2017 0:00
# 1    3/3/2020 0:00
# 2   8/19/2019 0:00
# 3  10/11/2017 0:00
# 4  10/11/2017 0:00

# %%
pcode['locality_address'] = pcode['Location'] + ", "+ pcode['Post_Office'] + ", " + pcode['Postcode'] + " "+ pcode['State'] + ", " + 'Malaysia'
pcode['locality_address']
# Out:
# 0        Estuari Garden, Iskandar Puteri, 79000 Johor, ...
# 1        Kota Ilmu Educity@Iskandar, Iskandar Puteri, 7...
# 2        Laman Estuari, Iskandar Puteri, 79000 Johor, M...
# 3        Pusat Pentadbiran Kerajaan Negeri Johor, Iskan...
# 4        Puteri Harbour, Iskandar Puteri, 79000 Johor, ...
#                                ...
# 71729    Suruhanjaya Kehakiman , Putrajaya, 62677 WP Pu...
# 71730    Suruhanjaya Pilihan Raya Malaysia, Putrajaya, ...
# 71731    Bahagian Hal Ehwal Undang-undang, Putrajaya, 6...
# 71732    Biro Bantuan Guaman Malaysia, Putrajaya, 62692...
# 71733    Cyberjaya, Putrajaya, 62988 WP Putrajaya, Mala...
# Name: locality_address, Length: 71734, dtype: object

# %%
pcode2 = pcode

# %%
pcode2.head()
# Out:
#                                   Location Postcode      Post_Office  State  \
# 0                           Estuari Garden    79000  Iskandar Puteri  Johor
# 1               Kota Ilmu Educity@Iskandar    79000  Iskandar Puteri  Johor
# 2                            Laman Estuari    79000  Iskandar Puteri  Johor
# 3  Pusat Pentadbiran Kerajaan Negeri Johor    79000  Iskandar Puteri  Johor
# 4                           Puteri Harbour    79000  Iskandar Puteri  Johor
#
#         DateUpdate                                   locality_address
# 0  10/11/2017 0:00  Estuari Garden, Iskandar Puteri, 79000 Johor, ...
# 1    3/3/2020 0:00  Kota Ilmu Educity@Iskandar, Iskandar Puteri, 7...
# 2   8/19/2019 0:00  Laman Estuari, Iskandar Puteri, 79000 Johor, M...
# 3  10/11/2017 0:00  Pusat Pentadbiran Kerajaan Negeri Johor, Iskan...
# 4  10/11/2017 0:00  Puteri Harbour, Iskandar Puteri, 79000 Johor, ...

# %%
# !pip install geopandas -qq
from geopandas.tools import geocode, geocoding, reverse_geocode

# %%
import geopy, inspect
print(geopy.__version__)

# use inspection, but limit to just classes
inspect.getmembers(geopy, predicate=inspect.isclass)
# Out:
# 2.3.0
# [('AlgoliaPlaces', geopy.geocoders.algolia.AlgoliaPlaces),
#  ('ArcGIS', geopy.geocoders.arcgis.ArcGIS),
#  ('AzureMaps', geopy.geocoders.azure.AzureMaps),
#  ('BANFrance', geopy.geocoders.banfrance.BANFrance),
#  ('Baidu', geopy.geocoders.baidu.Baidu),
#  ('BaiduV3', geopy.geocoders.baidu.BaiduV3),
#  ('Bing', geopy.geocoders.bing.Bing),
#  ('DataBC', geopy.geocoders.databc.DataBC),
#  ('GeoNames', geopy.geocoders.geonames.GeoNames),
#  ('GeocodeEarth', geopy.geocoders.geocodeearth.GeocodeEarth),
#  ('Geocodio', geopy.geocoders.geocodio.Geocodio),
#  ('Geolake', geopy.geocoders.geolake.Geolake),
#  ('GoogleV3', geopy.geocoders.google.GoogleV3),
#  ('Here', geopy.geocoders.here.Here),
#  ('HereV7', geopy.geocoders.here.HereV7),
#  ('IGNFrance', geopy.geocoders.ignfrance.IGNFrance),
#  ('LiveAddress', geopy.geocoders.smartystreets.LiveAddress),
#  ('Location', geopy.location.Location),
#  ('MapBox', geopy.geocoders.mapbox.MapBox),
#  ('MapQuest', geopy.geocoders.mapquest.MapQuest),
#  ('MapTiler', geopy.geocoders.maptiler.MapTiler),
#  ('Nominatim', geopy.geocoders.nominatim.Nominatim),
#  ('OpenCage', geopy.geocoders.opencage.OpenCage),
#  ('OpenMapQuest', geopy.geocoders.openmapquest.OpenMapQuest),
#  ('Pelias', geopy.geocoders.pelias.Pelias),
#  ('Photon', geopy.geocoders.photon.Photon),
#  ('PickPoint', geopy.geocoders.pickpoint.PickPoint),
#  ('Point', geopy.point.Point),
#  ('Timezone', geopy.timezone.Timezone),
#  ('TomTom', geopy.geocoders.tomtom.TomTom),
#  ('What3Words', geopy.geocoders.what3words.What3Words),
#  ('What3WordsV3', geopy.geocoders.what3words.What3WordsV3),
#  ('Yandex', geopy.geocoders.yandex.Yandex)]

# %% [markdown]
# ### bulk search address coordinate

# %%
test = pcode.head(10)

# %%
pcode_lnglat = geocode(strings=test['locality_address'], provider='arcgis') # Nominatim / Photon / ArcGIS
pcode_lnglat.head()
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Read timed out. (read timeout=1)")': /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=Kota+Ilmu+Educity%40Iskandar%2C+Iskandar+Puteri%2C+79000+Johor%2C+Malaysia&f=json&maxLocations=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Read timed out. (read timeout=1)")': /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=Laman+Estuari%2C+Iskandar+Puteri%2C+79000+Johor%2C+Malaysia&f=json&maxLocations=1
#                     geometry  \
# 0  POINT (103.65405 1.42971)
# 1  POINT (103.65897 1.42809)
# 2  POINT (103.65897 1.42809)
# 3  POINT (103.65897 1.42809)
# 4  POINT (103.65792 1.41910)
#
#                                              address
# 0                                    ESTUARI GARDENS
# 1                                              79000
# 2                                              79000
# 3                                              79000
# 4  79000, Puteri Harbour, Iskandar Puteri, Johor ...

# %%
df = pcode

# %%
geocode(strings='JABATAN PERANGKAAN NEGERI TERENGGANU, TERENGGANU, MALAYSIA', provider='arcgis')
# Out:
#                     geometry             address
# 0  POINT (103.14339 5.32863)  Jabatan Perangkaan

# %% [markdown]
# ## Flow mapping address
# 1. extract postcode
#
# 2. have postcode
#     - postcode API >> bandar and state <br><br>
#
# 3. not postcode
#     - textcontain dictionary(district) >> district
#     - textcontain dictionary(bandar) >> bandar
#     - lonlat >> kawasanku API >> district

# %% [markdown]
# ### Using state/district existing text

# %%
pcode2 = pcode

# %%
pcode2.head()
# Out:
#                                   Location Postcode      Post_Office  State  \
# 0                           Estuari Garden    79000  Iskandar Puteri  Johor
# 1               Kota Ilmu Educity@Iskandar    79000  Iskandar Puteri  Johor
# 2                            Laman Estuari    79000  Iskandar Puteri  Johor
# 3  Pusat Pentadbiran Kerajaan Negeri Johor    79000  Iskandar Puteri  Johor
# 4                           Puteri Harbour    79000  Iskandar Puteri  Johor
#
#         DateUpdate                                   locality_address
# 0  10/11/2017 0:00  Estuari Garden, Iskandar Puteri, 79000 Johor, ...
# 1    3/3/2020 0:00  Kota Ilmu Educity@Iskandar, Iskandar Puteri, 7...
# 2   8/19/2019 0:00  Laman Estuari, Iskandar Puteri, 79000 Johor, M...
# 3  10/11/2017 0:00  Pusat Pentadbiran Kerajaan Negeri Johor, Iskan...
# 4  10/11/2017 0:00  Puteri Harbour, Iskandar Puteri, 79000 Johor, ...

# %%
dfn = pcode2

# %%
dfn['locality_address'] = dfn['locality_address'].str.upper()

# %%
dfn.head()
# Out:
#                                   Location Postcode      Post_Office  State  \
# 0                           Estuari Garden    79000  Iskandar Puteri  Johor
# 1               Kota Ilmu Educity@Iskandar    79000  Iskandar Puteri  Johor
# 2                            Laman Estuari    79000  Iskandar Puteri  Johor
# 3  Pusat Pentadbiran Kerajaan Negeri Johor    79000  Iskandar Puteri  Johor
# 4                           Puteri Harbour    79000  Iskandar Puteri  Johor
#
#         DateUpdate                                   locality_address
# 0  10/11/2017 0:00  ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...
# 1    3/3/2020 0:00  KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...
# 2   8/19/2019 0:00  LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...
# 3  10/11/2017 0:00  PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...
# 4  10/11/2017 0:00  PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...

# %% [markdown]
# #### extract postcode

# %%
# Regular expression to match a continuous number
pattern = r'(\d{5})'

# Extract postcode and create a new column
dfn['postcode_new'] = dfn['locality_address'].str.extract(pattern)

# %%
dfn.head()
# Out:
#                                   Location Postcode      Post_Office  State  \
# 0                           Estuari Garden    79000  Iskandar Puteri  Johor
# 1               Kota Ilmu Educity@Iskandar    79000  Iskandar Puteri  Johor
# 2                            Laman Estuari    79000  Iskandar Puteri  Johor
# 3  Pusat Pentadbiran Kerajaan Negeri Johor    79000  Iskandar Puteri  Johor
# 4                           Puteri Harbour    79000  Iskandar Puteri  Johor
#
#         DateUpdate                                   locality_address  \
# 0  10/11/2017 0:00  ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...
# 1    3/3/2020 0:00  KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...
# 2   8/19/2019 0:00  LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...
# 3  10/11/2017 0:00  PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...
# 4  10/11/2017 0:00  PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...
#
#   postcode_new
# 0        79000
# 1        79000
# 2        79000
# 3        79000
# 4        79000

# %%
set(dfn['postcode_new'])
# Out:
# {'89139',
#  '89658',
#  '14400',
#  '28050',
#  '44110',
#  '20922',
#  '10998',
#  '62576',
#  '36200',
#  '10990',
#  '45609',
#  '50644',
#  '62616',
#  '36000',
#  '15518',
#  '93720',
#  '90706',
#  '10113',
#  '50250',
#  '18400',
#  '12405',
#  '79626',
#  '94800',
#  '25720',
#  '96010',
#  '28600',
#  '46050',
#  '71550',
#  '40505',
#  '15644',
#  '75910',
#  '28709',
#  '62675',
#  '12871',
#  '12200',
#  '20710',
#  '97015',
#  '11546',
#  '10244',
#  '62524',
#  '81850',
#  '25710',
#  '30546',
#  '88572',
#  '81100',
#  '79150',
#  '20566',
#  '10980',
#  '71409',
#  '79250',
#  '16109',
#  '71609',
#  '36700',
#  '72127',
#  '88505',
#  '09310',
#  '20518',
#  '17040',
#  '61561',
#  '84000',
#  '51990',
#  '70560',
#  '25100',
#  '33700',
#  '75902',
#  '11966',
#  '62596',
#  '70576',
#  '78307',
#  '88634',
#  '88992',
#  '46797',
#  '12211',
#  '75503',
#  '22621',
#  '26150',
#  '80150',
#  '22307',
#  '35909',
#  '12444',
#  '46400',
#  '80648',
#  '15540',
#  '90722',
#  '06760',
#  '26450',
#  '32500',
#  '80622',
#  '13691',
#  '28330',
#  '12226',
#  '46000',
#  '05674',
#  '93708',
#  '30900',
#  '15628',
#  '10250',
#  '09007',
#  '50546',
#  '56100',
#  '12300',
#  '32400',
#  '75460',
#  '70610',
#  '88995',
#  '12216',
#  '72100',
#  '31050',
#  '93520',
#  '88661',
#  '17507',
#  '10920',
#  '88670',
#  '89508',
#  '15586',
#  '05592',
#  '75646',
#  '13881',
#  '50596',
#  '06150',
#  '15680',
#  '15532',
#  '93900',
#  '25622',
#  '27150',
#  '93677',
#  '39100',
#  '30644',
#  '88000',
#  '40716',
#  '12356',
#  '55926',
#  '41050',
#  '30503',
#  '90739',
#  '50536',
#  '30510',
#  '11711',
#  '11091',
#  '08507',
#  '25673',
#  '94900',
#  '02709',
#  '02800',
#  '93904',
#  '45700',
#  '05580',
#  '60201',
#  '12036',
#  '15400',
#  '79680',
#  '71809',
#  '05621',
#  '30606',
#  '71950',
# dfn['negeri_tempat_tinggal'] = [x.split(',')[-1].strip() if pd.notna(x) and ',' in x else '' for x in dfn['alamat_tempat_tinggal']]

statelist = ['JOHOR', 'KEDAH', 'KELANTAN',
'MELAKA', 'NEGERI SEMBILAN',
'PAHANG', 'PERAK', 'PERLIS',
'PULAU PINANG', 'SABAH',
'SARAWAK', 'SELANGOR',
'TERENGGANU',
'PUTRAJAYA',
'LABUAN','KUALA LUMPUR']

dfn['negeri_'] = ''

for state in statelist:
    dfn['locality_address'].fillna('', inplace=True)
    mask = dfn['locality_address'].str.contains(state, case=False)
    dfn.loc[mask, 'negeri_'] = state

# %%
dfn.head()
# Out:
#                                   Location Postcode      Post_Office  State  \
# 0                           Estuari Garden    79000  Iskandar Puteri  Johor
# 1               Kota Ilmu Educity@Iskandar    79000  Iskandar Puteri  Johor
# 2                            Laman Estuari    79000  Iskandar Puteri  Johor
# 3  Pusat Pentadbiran Kerajaan Negeri Johor    79000  Iskandar Puteri  Johor
# 4                           Puteri Harbour    79000  Iskandar Puteri  Johor
#
#         DateUpdate                                   locality_address  \
# 0  10/11/2017 0:00  ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...
# 1    3/3/2020 0:00  KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...
# 2   8/19/2019 0:00  LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...
# 3  10/11/2017 0:00  PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...
# 4  10/11/2017 0:00  PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...
#
#   postcode_new negeri_
# 0        79000   JOHOR
# 1        79000   JOHOR
# 2        79000   JOHOR
# 3        79000   JOHOR
# 4        79000   JOHOR

# %%
dfn.shape
# Out:
# (71734, 8)

# %% [markdown]
# #### mapping with district dictionary

# %%
dist = pd.read_csv('https://github.com/dosm-malaysia/data-open/raw/main/datasets/geodata/state_district.csv')
dist.head()
# Out:
#    state     district  code_state  code_district code_state_district
# 0  Johor   Batu Pahat           1              1                 1_1
# 1  Johor  Johor Bahru           1              2                 1_2
# 2  Johor       Kluang           1              3                 1_3
# 3  Johor  Kota Tinggi           1              4                 1_4
# 4  Johor      Mersing           1              5                 1_5

# %%
# Extract 'district' column to a list
districtlist = dist['district'].tolist()

# Convert all strings to uppercase
districtlist = [item.upper() for item in districtlist]

# Additional items to add to the list
additional_items = ['KUALA LUMPUR', 'PUTRAJAYA', 'LABUAN', 'ISKANDAR PUTERI']

# Add additional items to the districtlist
districtlist.extend(additional_items)

dfn['district_'] = ''

for district in districtlist:
    dfn['locality_address'].fillna('', inplace=True)
    mask = dfn['locality_address'].str.contains(district, case=False)
    dfn.loc[mask, 'district_'] = district

# %%
dfn.tail()
# Out:
#                                 Location Postcode Post_Office         State  \
# 71729             Suruhanjaya Kehakiman     62677   Putrajaya  WP Putrajaya
# 71730  Suruhanjaya Pilihan Raya Malaysia    62686   Putrajaya  WP Putrajaya
# 71731   Bahagian Hal Ehwal Undang-undang    62692   Putrajaya  WP Putrajaya
# 71732       Biro Bantuan Guaman Malaysia    62692   Putrajaya  WP Putrajaya
# 71733                          Cyberjaya    62988   Putrajaya  WP Putrajaya
#
#             DateUpdate                                   locality_address  \
# 71729  6/22/2009 17:23  SURUHANJAYA KEHAKIMAN , PUTRAJAYA, 62677 WP PU...
# 71730  6/22/2009 17:23  SURUHANJAYA PILIHAN RAYA MALAYSIA, PUTRAJAYA, ...
# 71731  6/22/2009 17:23  BAHAGIAN HAL EHWAL UNDANG-UNDANG, PUTRAJAYA, 6...
# 71732  6/22/2009 17:23  BIRO BANTUAN GUAMAN MALAYSIA, PUTRAJAYA, 62692...
# 71733  6/22/2009 17:23  CYBERJAYA, PUTRAJAYA, 62988 WP PUTRAJAYA, MALA...
#
#       postcode_new    negeri_  district_
# 71729        62677  PUTRAJAYA  PUTRAJAYA
# 71730        62686  PUTRAJAYA  PUTRAJAYA
# 71731        62692  PUTRAJAYA  PUTRAJAYA
# 71732        62692  PUTRAJAYA  PUTRAJAYA
# 71733        62988  PUTRAJAYA  PUTRAJAYA

# %% [markdown]
# #### mapping with bandar dictionary

# %%
bandarlist = ['Ajil',
 'Al Muktatfi Billah Shah',
 'Alor GAjah',
 'Alor Gajah',
 'Alor Setar',
 'Alor gajah',
 'Ampang',
 'Arau',
 'Asahan',
 'Asajaya',
 'Ayer Baloi',
 'Ayer Hitam',
 'Ayer Itam',
 'Ayer Keroh',
 'Ayer Lanas',
 'Ayer Puteh',
 'Ayer Tawar',
 'Ayer Tawar 2',
 'Bachok',
 'Bagan Datoh',
 'Bagan Serai',
 'Bahau',
 'Balik Pulau',
 'Baling',
 'Baling ',
 'Balingian',
 'Balok',
 'Bandar Baharu',
 'Bandar Baru Bangi',
 'Bandar Bera',
 'Bandar Enstek',
 'Bandar Penawar',
 'Bandar Puncak Alam',
 'Bandar Pusat  Jengka',
 'Bandar Pusat Jengka',
 'Bandar Seri Iskandar',
 'Bandar Seri Jempol',
 'Bandar Tenggara',
 'Bandar Tun Abdul Razak',
 'Banting',
 'Baram',
 'Baram ',
 'Batang Kali',
 'Batu Anam',
 'Batu Arang',
 'Batu Caves',
 'Batu Ferringhi',
 'Batu Gajah',
 'Batu Kikir',
 'Batu Kurau',
 'Batu Maung',
 'Batu Pahat',
 'Bau',
 'Bayan Lepas',
 'Beaufort',
 'Bedong',
 'Behrang Stesen',
 'Bekenu',
 'Bekok',
 'Belaga',
 'Belaga ',
 'Belawai',
 'Beluran',
 'Bemban',
 'Benta',
 'Bentong',
 'Benut',
 'Beranang',
 'Bestari Jaya',
 'Betong',
 'Beverly',
 'Bidor',
 'Bintangor',
 'Bintulu',
 'Bongawan',
 'Bota',
 'Brinchang',
 'Bruas',
 'Bukit Besi',
 'Bukit Fraser',
 'Bukit Gambir',
 'Bukit Goh',
 'Bukit Kayu Hitam',
 'Bukit Kuin',
 'Bukit Mertajam',
 'Bukit Pasir',
 'Bukit Payong',
 'Bukit Rotan',
 'Butterworth',
 'Ceneh',
 'Chaah',
 'Chalok',
 'Changkat Jering',
 'Changkat Keruing',
 'Changloon',
 'Chemor',
 'Chenderiang',
 'Chenderong Balai',
 'Chenor',
 'Cherang Ruku',
 'Cheras',
 'Chikus',
 'Chini',
 'Cukai',
 'Cyberjaya',
 'Dabong',
 'Dalat',
 'Damak',
 'Daro',
 'Debak',
 'Dengkil',
 'Dong',
 'Dungun',
 'Durian Tunggal',
 'Endau',
 'Enggor',
 'Engkilili',
 'Gambang',
 'Gelang Patah',
 'Gelugor',
 'Gemas',
 'Gemencheh',
 'Genting Highlands',
 'Gerik',
 'Gerisek',
 'Gopeng',
 'Gua Musang',
 'Gugusan Taib Andak',
 'Gurun',
 'Hulu Langat',
 'Hutan Melintang',
 'Inanam',
 'Intan',
 'Ipoh',
 'Iskandar Puteri',
 'Jasin',
 'Jeli',
 'Jelutong',
 'Jementah',
 'Jeniang',
 'Jenjarom',
 'Jeram',
 'Jerantut',
 'Jerteh',
 'Jitra',
 'Johol',
 'Johor Bahru',
 'Julau',
 'KLIA',
 'Kabong',
 'Kahang',
 'Kajang',
 'Kajang ',
 'Kaki Bukit',
 'Kampar',
 'Kampung Gajah',
 'Kampung Kepayang',
 'Kampung Raja',
 'Kamunting',
 'Kangar',
 'Kanowit',
 'Kapar',
 'Kapit',
 'Karak',
 'Karangan',
 'Kem Desa Pahlawan',
 'Kem Trendak',
 'Kemasek',
 'Kemayan',
 'Keningau',
 'Kepala Batas',
 'Kerling',
 'Kerteh',
 'Ketengah Jaya',
 'Ketereh',
 'Kijal',
 'Klang',
 'Kluang',
 'Kodiang',
 'Kota',
 'Kota Belud',
 'Kota Bharu',
 'Kota Kinabalu',
 'Kota Kinabatangan',
 'Kota Kuala Muda',
 'Kota Marudu',
 'Kota Samarahan',
 'Kota Sarang Semut',
 'Kota Tinggi',
 'Kuala Balah',
 'Kuala Berang',
 'Kuala Besut',
 'Kuala Kangsar',
 'Kuala Kedah',
 'Kuala Ketil',
 'Kuala Klawang',
 'Kuala Krai',
 'Kuala Krau',
 'Kuala Kubu Baru',
 'Kuala Kurau',
 'Kuala Lipis',
 'Kuala Lumpur',
 'Kuala Nerang',
 'Kuala Pegang',
 'Kuala Penyu',
 'Kuala Perlis',
 'Kuala Pilah',
 'Kuala Rompin',
 'Kuala Selangor',
 'Kuala Sepetang',
 'Kuala Sungai Baru',
 'Kuala Terengganu',
 'Kuang',
 'Kuantan',
 'Kuantan ',
 'Kubang Semang',
 'Kuching',
 'Kudat',
 'Kukup',
 'Kulai',
 'Kulim',
 'Kunak',
 'Kupang',
 'Labis',
 'Labu',
 'Labuan',
 'Lahad Datu',
 'Lambor Kanan',
 'Lanchang',
 'Langgar',
 'Langkap',
 'Langkawi',
 'Lawas',
 'Layang-Layang',
 'Lenggong',
 'Likas',
 'Limbang',
 'Lingga',
 'Linggi',
 'Long Lama',
 'Lubok Antu',
 'Lubok China',
 'Lumut',
 'Lunas',
 'Lunas ',
 'Lundu',
 'Lurah Bilut',
 'Lutong',
 'Machang',
 'Malim Nawar',
 'Manong',
 'Mantin',
 'Maran',
 'Marang',
 'Masai',
 'Masjid Tanah',
 'Matang',
 'Matu',
 'Melaka',
 'Melaka ',
 'Melor',
 'Membakut',
 'Mentakab',
 'Menumbok',
 'Merbok',
 'Merlimau',
 'Mersing',
 'Miri',
 'Muadzam Shah',
 'Muar',
 'Mukah',
 'Nabawan',
 'Nanga Medamit',
 'Niah',
 'Niai',
 'Nibong Tebal',
 'Nilai',
 'Nilai ',
 'Padang Besar',
 'Padang Rengas',
 'Padang Serai',
 'Padang Tengku',
 'Pagoh',
 'Paka',
 'Paloh',
 'Pamol',
 'Panchor',
 'Pangkor',
 'Pantai Remis',
 'Papar',
 'Parit',
 'Parit Buntar',
 'Parit Jawa',
 'Parit Raja',
 'Parit Sulong',
 'Pasir Gudang',
 'Pasir Mas',
 'Pasir Puteh',
 'Pekan',
 'Pekan Nenas',
 'Pelabuhan Klang',
 'Penaga',
 'Penampang',
 'Penang Hill',
 'Pendang',
 'Pengerang',
 'Pengkalan Hulu',
 'Perai',
 'Permaisuri',
 'Permatang Pauh',
 'Petaling Jaya',
 'Pokok Sena',
 'Pontian',
 'Port Dickson',
 'Puchong',
 'Pulai Chondong',
 'Pulau Carey',
 'Pulau Indah',
 'Pulau Ketam',
 'Pulau Pinang',
 'Pulau Satu',
 'Pusa',
 'Pusat  Bandar Palong',
 'Pusat Mel Miri',
 'Pusing',
 'Putatan',
 'Putrajaya',
 'Ranau',
 'Ranau ',
 'Rantau',
 'Rantau Panjang',
 'Rasa',
 'Raub',
 'Rawang',
 'Rembau',
 'Rengam',
 'Rengit',
 'Ringlet',
 'Roban',
 'Rompin',
 'Sabak Bernam',
 'Sandakan',
 'Saratok',
 'Sarikei',
 'Sauk',
 'Sebauh',
 'Sebuyau',
 'Sega',
 'Segamat',
 'Sekinchan',
 'Selama',
 'Selandar',
 'Selekoh',
 'Selising',
 'Semenyih',
 'Semerah',
 'Semporna',
 'Senai',
 'Senggarang',
 'Sepang',
 'Serdang',
 'Seremban',
 'Seremban ',
 'Serendah',
 'Seri Gading',
 'Seri Kembangan',
 'Seri Manjong',
 'Seri Manjung',
 'Seri Medan',
 'Serian',
 'Shah Alam',
 'Shah Alam ',
 'Si Rusa',
 'Sibu',
 'Sibu Jaya',
 'Siburan',
 'Sik',
 'Simpang',
 'Simpang Ampat',
 'Simpang Ampat Semanggol',
 'Simpang Durian',
 'Simpang Empat',
 'Simpang Pertang',
 'Simpang Rengam',
 'Simunjan',
 'Sipitang',
 'Sitiawan',
 'Slim River',
 'Song',
 'Spaoh',
 'Sri Aman',
 'Subang Jaya',
 'Sundar',
 'Sungai Ayer Tawar',
 'Sungai Besar',
 'Sungai Buloh',
 'Sungai Jawi',
 'Sungai Koyan',
 'Sungai Lembing',
 'Sungai Mati',
 'Sungai Pelek',
 'Sungai Petani',
 'Sungai Rambai',
 'Sungai Siput',
 'Sungai Sumun',
 'Sungai Tong',
 'Sungai Udang',
 'Sungkai',
 'TLDM Lumut',
 'Taiping',
 'Tambunan',
 'Tamparuli',
 'Tampin',
 'Tanah Merah',
 'Tanah Rata',
 'Tangkak',
 'Tanjong Bungah',
 'Tanjong Ipoh',
 'Tanjong Karang',
 'Tanjong Kling',
 'Tanjong Malim',
 'Tanjong Piandang',
 'Tanjong Rambutan',
 'Tanjong Sepat',
 'Tanjong Tualang',
 'Tanjung Aru',
 'Tanjung Bungah',
 'Tanjung Sepat',
 'Tapah',
 'Tapah Road',
 'Tasek Gelugor',
 'Tasek Gelugur',
 'Tatau',
 'Tawau',
 'Telok Panglima Garang',
 'Teluk Intan',
 'Temangan',
 'Temerloh',
 'Temerloh ',
 'Temoh',
 'Tenghilan',
 'Tenom',
 'Triang',
 'Trolak',
 'Trong',
 'Tronoh',
 'Tuaran',
 'Tumpat',
 'USM Pulau Pinang',
 'Ulu Bernam',
 'Ulu Kinta',
 'Ulu Tiram',
 'Universiti Utara Malaysia',
 'Wakaf Bharu',
 'Yan',
 'Yong Peng']

# %%
# Convert all strings to uppercase
bandarlists = [item.upper() for item in bandarlist]

# %%
dfn['bandar_'] = ''

for bandar in bandarlists:
    dfn['locality_address'].fillna('', inplace=True)
    mask = dfn['locality_address'].str.contains(bandar, case=False)
    dfn.loc[mask, 'bandar_'] = bandar

# %%
dfn.tail()
# Out:
#                                 Location Postcode Post_Office         State  \
# 71729             Suruhanjaya Kehakiman     62677   Putrajaya  WP Putrajaya
# 71730  Suruhanjaya Pilihan Raya Malaysia    62686   Putrajaya  WP Putrajaya
# 71731   Bahagian Hal Ehwal Undang-undang    62692   Putrajaya  WP Putrajaya
# 71732       Biro Bantuan Guaman Malaysia    62692   Putrajaya  WP Putrajaya
# 71733                          Cyberjaya    62988   Putrajaya  WP Putrajaya
#
#             DateUpdate                                   locality_address  \
# 71729  6/22/2009 17:23  SURUHANJAYA KEHAKIMAN , PUTRAJAYA, 62677 WP PU...
# 71730  6/22/2009 17:23  SURUHANJAYA PILIHAN RAYA MALAYSIA, PUTRAJAYA, ...
# 71731  6/22/2009 17:23  BAHAGIAN HAL EHWAL UNDANG-UNDANG, PUTRAJAYA, 6...
# 71732  6/22/2009 17:23  BIRO BANTUAN GUAMAN MALAYSIA, PUTRAJAYA, 62692...
# 71733  6/22/2009 17:23  CYBERJAYA, PUTRAJAYA, 62988 WP PUTRAJAYA, MALA...
#
#       postcode_new    negeri_  district_    bandar_
# 71729        62677  PUTRAJAYA  PUTRAJAYA  PUTRAJAYA
# 71730        62686  PUTRAJAYA  PUTRAJAYA  PUTRAJAYA
# 71731        62692  PUTRAJAYA  PUTRAJAYA  PUTRAJAYA
# 71732        62692  PUTRAJAYA  PUTRAJAYA  PUTRAJAYA
# 71733        62988  PUTRAJAYA  PUTRAJAYA  PUTRAJAYA

# %% [markdown]
# #### check mapping data

# %%
dfn[dfn['negeri_']=='KELANTAN']
# Out:
#                                             Location Postcode   Post_Office  \
# 4042                                Kampung Kelantan    81900   Kota Tinggi
# 5623                                  Parit Kelantan    83500  Parit Sulong
# 5972                                Kampung Kelantan    84000          Muar
# 11151                               Kampung Kelantan    06900           Yan
# 13073  Apartment Pelangi Mall Jalan Post Office Lama    15000    Kota Bharu
# ...                                              ...      ...           ...
# 18492                                         Tandak    18500       Machang
# 18493                                  Temangan Lama    18500       Machang
# 18494                                      To Chanor    18500       Machang
# 18495                                        Tok Bok    18500       Machang
# 18496                        Wakaf Bata Gelong Gajah    18500       Machang
#
#           State       DateUpdate  \
# 4042      Johor  6/22/2009 17:23
# 5623      Johor  6/22/2009 17:23
# 5972      Johor  6/22/2009 17:23
# 11151     Kedah  6/22/2009 17:23
# 13073  Kelantan  6/22/2009 17:23
# ...         ...              ...
# 18492  Kelantan  6/22/2009 17:23
# 18493  Kelantan  6/22/2009 17:23
# 18494  Kelantan  6/22/2009 17:23
# 18495  Kelantan  6/22/2009 17:23
# 18496  Kelantan  6/22/2009 17:23
#
#                                         locality_address postcode_new  \
# 4042   KAMPUNG KELANTAN, KOTA TINGGI, 81900 JOHOR, MA...        81900
# 5623   PARIT KELANTAN, PARIT SULONG, 83500 JOHOR, MAL...        83500
# 5972       KAMPUNG KELANTAN, MUAR, 84000 JOHOR, MALAYSIA        84000
# 11151       KAMPUNG KELANTAN, YAN, 06900 KEDAH, MALAYSIA        06900
# 13073  APARTMENT PELANGI MALL JALAN POST OFFICE LAMA,...        15000
# ...                                                  ...          ...
# 18492          TANDAK, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18493   TEMANGAN LAMA, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18494       TO CHANOR, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18495         TOK BOK, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18496  WAKAF BATA GELONG GAJAH, MACHANG, 18500 KELANT...        18500
#
#         negeri_    district_       bandar_
# 4042   KELANTAN  KOTA TINGGI   KOTA TINGGI
# 5623   KELANTAN               PARIT SULONG
# 5972   KELANTAN         MUAR          MUAR
# 11151  KELANTAN          YAN           YAN
# 13073  KELANTAN   KOTA BHARU    KOTA BHARU
# ...         ...          ...           ...
# 18492  KELANTAN      MACHANG       MACHANG
# 18493  KELANTAN      MACHANG      TEMANGAN
# 18494  KELANTAN      MACHANG       MACHANG
# 18495  KELANTAN      MACHANG       MACHANG
# 18496  KELANTAN      MACHANG       MACHANG
#
# [5421 rows x 10 columns]

# %% [markdown]
# wrongly mapping
# 1. YAN in KEDAH
# 2. Kampung Kelatan di Kedah dan Kota Tinggi and Muar, Johor
# 3. Parit Kelantan di Johor

# %% [markdown]
# ### Using postcode API

# %%
import pandas as pd
from tqdm import tqdm
import urllib.request
import json
from shapely.geometry import shape, Point
import time
import warnings

time_start = time.time()
tqdm.pandas()

# Load pcode and dfn DataFrames
pcode = pd.read_csv("https://raw.githubusercontent.com/booluckgmie/training/main/python/kawasanku/poskodM_2020.csv", dtype={'Postcode':str})
# Assuming dfn DataFrame is already loaded

# Group the pcode DataFrame by 'Postcode' and convert each group into a dictionary
postcode_to_state_location = pcode.groupby('Postcode').apply(lambda x: {
    'Location': x['Location'].iloc[0],
    'Post_Office': x['Post_Office'].iloc[0],
    'State': x['State'].iloc[0],
}).to_dict()

# Validate the input postcode and lookup the state and location
def get_state_location_info(postcode):
    return postcode_to_state_location.get(postcode, None)

# Progress tracker while processing the DataFrame
total_rows = len(dfn)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # Ignore all warnings
    for idx, row in tqdm(dfn.iterrows(), total=total_rows, desc="Processing DataFrame"):
        postcode = row['Postcode']
        state_location_info = get_state_location_info(postcode)

        if state_location_info:
            dfn.at[idx, 'state_new'] = state_location_info['State']
            dfn.at[idx, 'post_office_new'] = state_location_info['Post_Office']
            dfn.at[idx, 'location_new'] = state_location_info['Location']

# Print the updated dfn DataFrame
dfn
# Out:
# Processing DataFrame: 100%|██████████| 71734/71734 [00:08<00:00, 8287.89it/s]
#                                       Location Postcode      Post_Office  \
# 0                               Estuari Garden    79000  Iskandar Puteri
# 1                   Kota Ilmu Educity@Iskandar    79000  Iskandar Puteri
# 2                                Laman Estuari    79000  Iskandar Puteri
# 3      Pusat Pentadbiran Kerajaan Negeri Johor    79000  Iskandar Puteri
# 4                               Puteri Harbour    79000  Iskandar Puteri
# ...                                        ...      ...              ...
# 71729                   Suruhanjaya Kehakiman     62677        Putrajaya
# 71730        Suruhanjaya Pilihan Raya Malaysia    62686        Putrajaya
# 71731         Bahagian Hal Ehwal Undang-undang    62692        Putrajaya
# 71732             Biro Bantuan Guaman Malaysia    62692        Putrajaya
# 71733                                Cyberjaya    62988        Putrajaya
#
#               State       DateUpdate  \
# 0             Johor  10/11/2017 0:00
# 1             Johor    3/3/2020 0:00
# 2             Johor   8/19/2019 0:00
# 3             Johor  10/11/2017 0:00
# 4             Johor  10/11/2017 0:00
# ...             ...              ...
# 71729  WP Putrajaya  6/22/2009 17:23
# 71730  WP Putrajaya  6/22/2009 17:23
# 71731  WP Putrajaya  6/22/2009 17:23
# 71732  WP Putrajaya  6/22/2009 17:23
# 71733  WP Putrajaya  6/22/2009 17:23
#
#                                         locality_address postcode_new  \
# 0      ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...        79000
# 1      KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...        79000
# 2      LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...        79000
# 3      PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...        79000
# 4      PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...        79000
# ...                                                  ...          ...
# 71729  SURUHANJAYA KEHAKIMAN , PUTRAJAYA, 62677 WP PU...        62677
# 71730  SURUHANJAYA PILIHAN RAYA MALAYSIA, PUTRAJAYA, ...        62686
# 71731  BAHAGIAN HAL EHWAL UNDANG-UNDANG, PUTRAJAYA, 6...        62692
# 71732  BIRO BANTUAN GUAMAN MALAYSIA, PUTRAJAYA, 62692...        62692
# 71733  CYBERJAYA, PUTRAJAYA, 62988 WP PUTRAJAYA, MALA...        62988
#
#          negeri_        district_          bandar_     state_new  \
# 0          JOHOR  ISKANDAR PUTERI  ISKANDAR PUTERI         Johor
# 1          JOHOR  ISKANDAR PUTERI             KOTA         Johor
# 2          JOHOR  ISKANDAR PUTERI  ISKANDAR PUTERI         Johor
# 3          JOHOR  ISKANDAR PUTERI             PUSA         Johor
# 4          JOHOR  ISKANDAR PUTERI  ISKANDAR PUTERI         Johor
# ...          ...              ...              ...           ...
# 71729  PUTRAJAYA        PUTRAJAYA        PUTRAJAYA  WP Putrajaya
# 71730  PUTRAJAYA        PUTRAJAYA        PUTRAJAYA  WP Putrajaya
# 71731  PUTRAJAYA        PUTRAJAYA        PUTRAJAYA  WP Putrajaya
# 71732  PUTRAJAYA        PUTRAJAYA        PUTRAJAYA  WP Putrajaya
# 71733  PUTRAJAYA        PUTRAJAYA        PUTRAJAYA  WP Putrajaya
#
#        post_office_new                       location_new
# 0      Iskandar Puteri                     Estuari Garden
# 1      Iskandar Puteri                     Estuari Garden
# 2      Iskandar Puteri                     Estuari Garden
# 3      Iskandar Puteri                     Estuari Garden
# 4      Iskandar Puteri                     Estuari Garden
# ...                ...                                ...
# 71729        Putrajaya             Suruhanjaya Kehakiman
# 71730        Putrajaya  Suruhanjaya Pilihan Raya Malaysia
# 71731        Putrajaya   Bahagian Hal Ehwal Undang-undang
# 71732        Putrajaya   Bahagian Hal Ehwal Undang-undang
# 71733        Putrajaya                          Cyberjaya
#
# [71734 rows x 13 columns]

# %%
dfn[dfn['negeri_']=='KELANTAN']
# Out:
#                                             Location Postcode   Post_Office  \
# 4042                                Kampung Kelantan    81900   Kota Tinggi
# 5623                                  Parit Kelantan    83500  Parit Sulong
# 5972                                Kampung Kelantan    84000          Muar
# 11151                               Kampung Kelantan    06900           Yan
# 13073  Apartment Pelangi Mall Jalan Post Office Lama    15000    Kota Bharu
# ...                                              ...      ...           ...
# 18492                                         Tandak    18500       Machang
# 18493                                  Temangan Lama    18500       Machang
# 18494                                      To Chanor    18500       Machang
# 18495                                        Tok Bok    18500       Machang
# 18496                        Wakaf Bata Gelong Gajah    18500       Machang
#
#           State       DateUpdate  \
# 4042      Johor  6/22/2009 17:23
# 5623      Johor  6/22/2009 17:23
# 5972      Johor  6/22/2009 17:23
# 11151     Kedah  6/22/2009 17:23
# 13073  Kelantan  6/22/2009 17:23
# ...         ...              ...
# 18492  Kelantan  6/22/2009 17:23
# 18493  Kelantan  6/22/2009 17:23
# 18494  Kelantan  6/22/2009 17:23
# 18495  Kelantan  6/22/2009 17:23
# 18496  Kelantan  6/22/2009 17:23
#
#                                         locality_address postcode_new  \
# 4042   KAMPUNG KELANTAN, KOTA TINGGI, 81900 JOHOR, MA...        81900
# 5623   PARIT KELANTAN, PARIT SULONG, 83500 JOHOR, MAL...        83500
# 5972       KAMPUNG KELANTAN, MUAR, 84000 JOHOR, MALAYSIA        84000
# 11151       KAMPUNG KELANTAN, YAN, 06900 KEDAH, MALAYSIA        06900
# 13073  APARTMENT PELANGI MALL JALAN POST OFFICE LAMA,...        15000
# ...                                                  ...          ...
# 18492          TANDAK, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18493   TEMANGAN LAMA, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18494       TO CHANOR, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18495         TOK BOK, MACHANG, 18500 KELANTAN, MALAYSIA        18500
# 18496  WAKAF BATA GELONG GAJAH, MACHANG, 18500 KELANT...        18500
#
#         negeri_    district_       bandar_ state_new post_office_new  \
# 4042   KELANTAN  KOTA TINGGI   KOTA TINGGI     Johor     Kota Tinggi
# 5623   KELANTAN               PARIT SULONG     Johor    Parit Sulong
# 5972   KELANTAN         MUAR          MUAR     Johor            Muar
# 11151  KELANTAN          YAN           YAN     Kedah             Yan
# 13073  KELANTAN   KOTA BHARU    KOTA BHARU  Kelantan      Kota Bharu
# ...         ...          ...           ...       ...             ...
# 18492  KELANTAN      MACHANG       MACHANG  Kelantan         Machang
# 18493  KELANTAN      MACHANG      TEMANGAN  Kelantan         Machang
# 18494  KELANTAN      MACHANG       MACHANG  Kelantan         Machang
# 18495  KELANTAN      MACHANG       MACHANG  Kelantan         Machang
# 18496  KELANTAN      MACHANG       MACHANG  Kelantan         Machang
#
#                                         location_new
# 4042                               Bandar Sri Perani
# 5623                          Batu 1 Jalan Yong Peng
# 5972                                      Ayer Hitam
# 11151                 Batu 21 1/4 - 24 3/4 Jalan Yan
# 13073  Apartment Pelangi Mall Jalan Post Office Lama
# ...                                              ...
# 18492                                           ALIA
# 18493                                           ALIA
# 18494                                           ALIA
# 18495                                           ALIA
# 18496                                           ALIA
#
# [5421 rows x 13 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (8 * figscale, 4.8 * figscale)
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_0, *['State'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (8 * figscale, 4.8 * figscale)
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_1, *['DateUpdate'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (8 * figscale, 4.8 * figscale)
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_2, *['state_new'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   figsize = (8 * figscale, 8 * figscale)
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_3, *['State', 'DateUpdate'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   figsize = (8 * figscale, 8 * figscale)
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_4, *['DateUpdate', 'state_new'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_5, *['DateUpdate', 'count()', 'State'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_6, *['DateUpdate', 'count()', 'DateUpdate'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_7, *['DateUpdate', 'count()', 'state_new'], **{})
# chart
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
dfn2 = dfn[['Postcode','State','locality_address','state_new','post_office_new','location_new']]
dfn2
# Out:
#       Postcode         State  \
# 0        79000         Johor
# 1        79000         Johor
# 2        79000         Johor
# 3        79000         Johor
# 4        79000         Johor
# ...        ...           ...
# 71729    62677  WP Putrajaya
# 71730    62686  WP Putrajaya
# 71731    62692  WP Putrajaya
# 71732    62692  WP Putrajaya
# 71733    62988  WP Putrajaya
#
#                                         locality_address     state_new  \
# 0      ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...         Johor
# 1      KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...         Johor
# 2      LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...         Johor
# 3      PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...         Johor
# 4      PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...         Johor
# ...                                                  ...           ...
# 71729  SURUHANJAYA KEHAKIMAN , PUTRAJAYA, 62677 WP PU...  WP Putrajaya
# 71730  SURUHANJAYA PILIHAN RAYA MALAYSIA, PUTRAJAYA, ...  WP Putrajaya
# 71731  BAHAGIAN HAL EHWAL UNDANG-UNDANG, PUTRAJAYA, 6...  WP Putrajaya
# 71732  BIRO BANTUAN GUAMAN MALAYSIA, PUTRAJAYA, 62692...  WP Putrajaya
# 71733  CYBERJAYA, PUTRAJAYA, 62988 WP PUTRAJAYA, MALA...  WP Putrajaya
#
#        post_office_new                       location_new
# 0      Iskandar Puteri                     Estuari Garden
# 1      Iskandar Puteri                     Estuari Garden
# 2      Iskandar Puteri                     Estuari Garden
# 3      Iskandar Puteri                     Estuari Garden
# 4      Iskandar Puteri                     Estuari Garden
# ...                ...                                ...
# 71729        Putrajaya             Suruhanjaya Kehakiman
# 71730        Putrajaya  Suruhanjaya Pilihan Raya Malaysia
# 71731        Putrajaya   Bahagian Hal Ehwal Undang-undang
# 71732        Putrajaya   Bahagian Hal Ehwal Undang-undang
# 71733        Putrajaya                          Cyberjaya
#
# [71734 rows x 6 columns]

# %%
dfn2[dfn2['State']=='Kelantan']
# Out:
#       Postcode     State                                   locality_address  \
# 13073    15000  Kelantan  APARTMENT PELANGI MALL JALAN POST OFFICE LAMA,...
# 13074    15000  Kelantan  BANGUNAN AIA, KOTA BHARU, 15000 KELANTAN, MALA...
# 13075    15000  Kelantan  BANGUNAN MGU, KOTA BHARU, 15000 KELANTAN, MALA...
# 13076    15000  Kelantan  HOTEL JUITA INN, KOTA BHARU, 15000 KELANTAN, M...
# 13077    15000  Kelantan  HOTEL RAUDAH JALAN MAJU, KOTA BHARU, 15000 KEL...
# ...        ...       ...                                                ...
# 18492    18500  Kelantan          TANDAK, MACHANG, 18500 KELANTAN, MALAYSIA
# 18493    18500  Kelantan   TEMANGAN LAMA, MACHANG, 18500 KELANTAN, MALAYSIA
# 18494    18500  Kelantan       TO CHANOR, MACHANG, 18500 KELANTAN, MALAYSIA
# 18495    18500  Kelantan         TOK BOK, MACHANG, 18500 KELANTAN, MALAYSIA
# 18496    18500  Kelantan  WAKAF BATA GELONG GAJAH, MACHANG, 18500 KELANT...
#
#       state_new post_office_new                                   location_new
# 13073  Kelantan      Kota Bharu  Apartment Pelangi Mall Jalan Post Office Lama
# 13074  Kelantan      Kota Bharu  Apartment Pelangi Mall Jalan Post Office Lama
# 13075  Kelantan      Kota Bharu  Apartment Pelangi Mall Jalan Post Office Lama
# 13076  Kelantan      Kota Bharu  Apartment Pelangi Mall Jalan Post Office Lama
# 13077  Kelantan      Kota Bharu  Apartment Pelangi Mall Jalan Post Office Lama
# ...         ...             ...                                            ...
# 18492  Kelantan         Machang                                           ALIA
# 18493  Kelantan         Machang                                           ALIA
# 18494  Kelantan         Machang                                           ALIA
# 18495  Kelantan         Machang                                           ALIA
# 18496  Kelantan         Machang                                           ALIA
#
# [5424 rows x 6 columns]

# %%
filtered_df = dfn[dfn['locality_address'].str.contains('PARIT KELANTAN, PARIT SULONG, 83500 JOHOR')]
filtered_df
# Out:
#             Location Postcode   Post_Office  State       DateUpdate  \
# 5623  Parit Kelantan    83500  Parit Sulong  Johor  6/22/2009 17:23
#
#                                        locality_address postcode_new  \
# 5623  PARIT KELANTAN, PARIT SULONG, 83500 JOHOR, MAL...        83500
#
#        negeri_ district_       bandar_ state_new post_office_new  \
# 5623  KELANTAN            PARIT SULONG     Johor    Parit Sulong
#
#                 location_new
# 5623  Batu 1 Jalan Yong Peng

# %% [markdown]
# ### API Kawasanku for District/DUN/Parlimen

# %%
dfn2.head()
# Out:
#   Postcode  State                                   locality_address  \
# 0    79000  Johor  ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...
# 1    79000  Johor  KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...
# 2    79000  Johor  LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...
# 3    79000  Johor  PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...
# 4    79000  Johor  PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...
#
#   state_new  post_office_new    location_new
# 0     Johor  Iskandar Puteri  Estuari Garden
# 1     Johor  Iskandar Puteri  Estuari Garden
# 2     Johor  Iskandar Puteri  Estuari Garden
# 3     Johor  Iskandar Puteri  Estuari Garden
# 4     Johor  Iskandar Puteri  Estuari Garden

# %%
dfc = dfn2.head(10)
# dfc.head()

# %%
# !pip install geopandas -qq
from geopandas.tools import geocode, geocoding, reverse_geocode
import pandas as pd
from shapely.geometry import Point

dfc[['coordinate','point_address']] = geocode(strings=dfc['locality_address'], provider='arcgis')

# # Extract lon and lat
dfc['lon'] = dfc['coordinate'].apply(lambda point: point.x)
dfc['lat'] = dfc['coordinate'].apply(lambda point: point.y)

# # # Drop the original geometry column
dfc.drop(columns=['coordinate'], inplace=True)

dfc.head()
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Read timed out. (read timeout=1)")': /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=KOTA+ILMU+EDUCITY%40ISKANDAR%2C+ISKANDAR+PUTERI%2C+79000+JOHOR%2C+MALAYSIA&f=json&maxLocations=1
# <ipython-input-75-de6a5f5ed810>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[['coordinate','point_address']] = geocode(strings=dfc['locality_address'], provider='arcgis')
# <ipython-input-75-de6a5f5ed810>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[['coordinate','point_address']] = geocode(strings=dfc['locality_address'], provider='arcgis')
# <ipython-input-75-de6a5f5ed810>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['lon'] = dfc['coordinate'].apply(lambda point: point.x)
# <ipython-input-75-de6a5f5ed810>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['lat'] = dfc['coordinate'].apply(lambda point: point.y)
# <ipython-input-75-de6a5f5ed810>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.drop(columns=['coordinate'], inplace=True)
#   Postcode  State                                   locality_address  \
# 0    79000  Johor  ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...
# 1    79000  Johor  KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...
# 2    79000  Johor  LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...
# 3    79000  Johor  PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...
# 4    79000  Johor  PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...
#
#   state_new  post_office_new    location_new  \
# 0     Johor  Iskandar Puteri  Estuari Garden
# 1     Johor  Iskandar Puteri  Estuari Garden
# 2     Johor  Iskandar Puteri  Estuari Garden
# 3     Johor  Iskandar Puteri  Estuari Garden
# 4     Johor  Iskandar Puteri  Estuari Garden
#
#                                        point_address         lon       lat
# 0                                    ESTUARI GARDENS  103.654050  1.429710
# 1                                              79000  103.658965  1.428087
# 2                                              79000  103.658965  1.428087
# 3                                              79000  103.658965  1.428087
# 4  79000, Puteri Harbour, Iskandar Puteri, Johor ...  103.657918  1.419097

# %%
import pandas as pd
from tqdm import tqdm
import urllib.request
import json
from shapely.geometry import shape, Point
import time

time_start = time.time()
tqdm.pandas()

PATH_GEOJSON = 'https://raw.githubusercontent.com/dosm-malaysia/data-open/main/datasets/geodata/'

geojsons = ['administrative_0_malaysia',
            'administrative_1_state',
            'administrative_2_district',
            'electoral_0_parlimen',
            'electoral_1_dun']

for i in range (len(geojsons)): geojsons[i] = PATH_GEOJSON + geojsons[i] + '.geojson'

states = json.load(urllib.request.urlopen(geojsons[1]))
districts = json.load(urllib.request.urlopen(geojsons[2]))
parlimens = json.load(urllib.request.urlopen(geojsons[3]))
duns = json.load(urllib.request.urlopen(geojsons[4]))
int_jsonfile = {1: states, 2: districts, 3: parlimens, 4: duns}

def reverse_geocode(lon,lat,geojson_file,name_field):
    try: point = Point(lon, lat)
    except Exception as e:
        print(e)
        return 'Error'

    for feature in geojson_file['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point): return (feature['properties'])[name_field].title()

    return 'OUT_OF_BOUNDS'

# %%
import warnings

# Ignore RuntimeWarning
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
levels = ['country','state','district','parlimen','dun']
for i in [1,2,3,4]:
    dfc[levels[i]] = dfc.progress_apply(lambda x: reverse_geocode(x['lon'], x['lat'], int_jsonfile[i], levels[i]), axis = 1)

dfc.head()
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 22.06it/s]
# <ipython-input-78-c998b4035b59>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[levels[i]] = dfc.progress_apply(lambda x: reverse_geocode(x['lon'], x['lat'], int_jsonfile[i], levels[i]), axis = 1)
# 100%|██████████| 10/10 [00:00<00:00, 584.81it/s]
# <ipython-input-78-c998b4035b59>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[levels[i]] = dfc.progress_apply(lambda x: reverse_geocode(x['lon'], x['lat'], int_jsonfile[i], levels[i]), axis = 1)
# 100%|██████████| 10/10 [00:00<00:00, 11.27it/s]
# <ipython-input-78-c998b4035b59>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[levels[i]] = dfc.progress_apply(lambda x: reverse_geocode(x['lon'], x['lat'], int_jsonfile[i], levels[i]), axis = 1)
# 100%|██████████| 10/10 [00:00<00:00, 58.20it/s]
# <ipython-input-78-c998b4035b59>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[levels[i]] = dfc.progress_apply(lambda x: reverse_geocode(x['lon'], x['lat'], int_jsonfile[i], levels[i]), axis = 1)
#   Postcode  State                                   locality_address  \
# 0    79000  Johor  ESTUARI GARDEN, ISKANDAR PUTERI, 79000 JOHOR, ...
# 1    79000  Johor  KOTA ILMU EDUCITY@ISKANDAR, ISKANDAR PUTERI, 7...
# 2    79000  Johor  LAMAN ESTUARI, ISKANDAR PUTERI, 79000 JOHOR, M...
# 3    79000  Johor  PUSAT PENTADBIRAN KERAJAAN NEGERI JOHOR, ISKAN...
# 4    79000  Johor  PUTERI HARBOUR, ISKANDAR PUTERI, 79000 JOHOR, ...
#
#   state_new  post_office_new    location_new  \
# 0     Johor  Iskandar Puteri  Estuari Garden
# 1     Johor  Iskandar Puteri  Estuari Garden
# 2     Johor  Iskandar Puteri  Estuari Garden
# 3     Johor  Iskandar Puteri  Estuari Garden
# 4     Johor  Iskandar Puteri  Estuari Garden
#
#                                        point_address         lon       lat  \
# 0                                    ESTUARI GARDENS  103.654050  1.429710
# 1                                              79000  103.658965  1.428087
# 2                                              79000  103.658965  1.428087
# 3                                              79000  103.658965  1.428087
# 4  79000, Puteri Harbour, Iskandar Puteri, Johor ...  103.657918  1.419097
#
#    state     district               parlimen                 dun
# 0  Johor  Johor Bahru  P.162 Iskandar Puteri  N.49 Kota Iskandar
# 1  Johor  Johor Bahru  P.162 Iskandar Puteri  N.49 Kota Iskandar
# 2  Johor  Johor Bahru  P.162 Iskandar Puteri  N.49 Kota Iskandar
# 3  Johor  Johor Bahru  P.162 Iskandar Puteri  N.49 Kota Iskandar
# 4  Johor  Johor Bahru  P.162 Iskandar Puteri  N.49 Kota Iskandar

# %%
dfc.to_csv('clean_geocode.csv', index=False)
